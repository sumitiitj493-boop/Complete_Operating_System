# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #58a6ff;">
#
# # 🚀 **Shortest Job First (SJF) Scheduling Algorithm**
# ## *Jisko kam kaam hai, usko pehle mauka!*
#
# <p style="color: #8b949e; font-size: 16px;">Operating Systems - CPU Scheduling Series | Bhai Style Explanation</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #30363d;">
#
# ## 🎬 **The Hook - Kahani Shuru Karte Hain!**
#
# ---
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture me hum fodne wale hai SJF Scheduling Algorithm... 💥**
#
# To kabhi socha hai aapne ki jab tum **Domino's** mein pizza order karte ho, aur tumhara order bada hai (like 5 pizzas + sides + drinks) but tumhare peeche wale ne sirf ek **Garlic Bread** order kiya hai...
#
# Ab agar wo bande ko bhi tumhare 20 minute wait karna pade sirf garlic bread ke liye... **Bechara ro dega na?** 😭
#
# Isliye smart restaurants kya karti hain? **Jo order jaldi ban sakta hai, usse pehle de do!** Garlic bread 2 min mein ready? Pehle de do! Pizza 15 min lagega? Wo baad mein!
#
# **Yahi hai SJF ka funda bhai!** Jo process sabse chhoti hai, usse pehle CPU do! Simple! 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ⏪ **Flashback Zone - "Yaad Hai Bhai?"**
#
# ---
#
# Lekin bhai, aage badhne se pehle kuch **basic concepts** clear karna zaroori hai. Professor ne assume kar liya ki tumhe sab yaad hai... but tension nahi, fatafat revise kar lete hain! 📚
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔄 **Yaad Hai? #1: FCFS (First Come First Serve) Kya Tha?**
#
# ---
#
# Bhai ye simple tha - **Jo pehle aaya, usko pehle CPU milega!**
#
# Jaise bank ki line - token number 1 wala pehle, chahe uska kaam 2 ghante ka ho ya 2 minute ka! 🏦
#
# **Problem kya thi?** Agar pehle wale ka kaam bada hai, toh baaki sab wait karte reh jayenge (isse bolte hain **Convoy Effect**)
#
# **Key Point:** FCFS ek **Non-Preemptive** algorithm tha - matlab ek baar CPU mil gaya toh koi cheenk nahi sakta!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🔄 **Yaad Hai? #2: CPU Burst Kya Hota Hai?**
#
# ---
#
# Socho ek process ka life cycle:
#
# ```
# CPU use karo → I/O karo → CPU use karo → I/O karo → ... → Khatam!
# ```
#
# Jab process **CPU use kar raha hai** - uss time period ko **CPU Burst** bolte hain! ⚡
#
# Jaise tum padh rahe ho (CPU Burst) → chai peene gaye (I/O Burst) → wapas padhai (CPU Burst)
#
# **Ek process ke multiple CPU bursts ho sakte hain!** Isliye hum "**Next CPU Burst**" ki baat karte hain - matlab agli baar jab CPU use karega, kitna time lagega!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔄 **Yaad Hai? #3: Preemptive vs Non-Preemptive Kya Scene Hai?**
#
# ---
#
# Ye bahut important hai bhai! 🎯
#
# | Type | Kya Hota Hai | Real Life Example |
# |------|--------------|-------------------|
# | **Non-Preemptive** | Ek baar CPU mila toh koi cheenk nahi sakta | Bathroom mein ghuse toh bahar nikalo tab tak wait! 🚽 |
# | **Preemptive** | Beech mein bhi CPU cheena ja sakta hai | Boss ka call aaye toh meeting chhodo, boss se baat karo! 📞 |
#
# **FCFS:** Sirf Non-Preemptive tha
#
# **SJF:** Dono ho sakta hai! (Aaj yahi seekhenge) 😎
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🔄 **Yaad Hai? #4: Gantt Chart Kya Hai?**
#
# ---
#
# Simple hai bhai! Ye ek **timeline diagram** hai jo dikhata hai ki kaunsa process kab se kab tak CPU use kar raha tha! 📊
#
# <pre style="background-color: #161b22; padding: 15px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌──────────┬──────────┬──────────┐
# │    P1    │    P2    │    P3    │
# └──────────┴──────────┴──────────┘
# 0          5          10         15
#            ↑          ↑          ↑
#         Time in milliseconds
# </pre>
#
# Isse dekh ke hum easily **waiting time** calculate kar sakte hain!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ✅ **Basics Clear! Ab Asli Masala Shuru!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# ## 🎯 **SJF Scheduling - The Main Concept**
#
# ---
#
# ### **Definition (Seedha Point!):**
#
# > **Jis process ka NEXT CPU BURST sabse CHHOTA hai, usse PEHLE CPU do!**
#
# ---
#
# ### **🍕 Analogy Samjho - Pizza Counter Story:**
#
# Imagine karo tum pizza counter pe kaam karte ho:
#
# - **Customer A:** 5 pizza order (15 min lagenge)
# - **Customer B:** 1 garlic bread (2 min lagenge)
# - **Customer C:** 3 pizza (10 min lagenge)
# - **Customer D:** 1 coke (30 sec lagenge)
#
# **FCFS kare toh?** A→B→C→D (A ke 15 min mein sab wait karenge) 😫
#
# **SJF kare toh?** D→B→C→A (Chhote orders pehle, bade baad mein) 🎉
#
# **Result?** Overall waiting time kam ho jata hai!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### ⚠️ **Important Clarification - Bahut Log Confuse Hote Hain!**
#
# ---
#
# **"Shortest Job" ka matlab TOTAL process length NAHI hai!**
#
# Matlab ye nahi ki poora process kitna time lega start se end tak...
#
# **Actual Meaning:** Agli baar jab ye process CPU use karega (**Next CPU Burst**), tab kitna time lagega!
#
# Isliye technically isse **"Shortest Next CPU Burst Algorithm"** bolna chahiye! 📝
#
# But exams mein **SJF** hi likhna hai! 😅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🤝 **Tie-Breaking Rule - Agar Dono Same Length Ke Hon?**
#
# ---
#
# Socho do processes hain:
# - P1: Burst Time = 5ms
# - P2: Burst Time = 5ms
#
# **Dono same! Ab kisko pehle dein?** 🤔
#
# **Answer:** Jab tie ho, toh **FCFS use karo!**
#
# Matlab jo pehle aaya, usse pehle CPU do!
#
# **Simple Rule:** SJF fail? → FCFS apply! ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ## 📊 **SJF Ke Do Avatars!**
#
# ---
#
# <pre style="background-color: #0d1117; padding: 20px; border-radius: 8px; color: #3fb950; white-space: pre; font-family: monospace; overflow-x: auto;">
#                     ┌─────────────────┐
#                     │  SJF Algorithm  │
#                     └────────┬────────┘
#                              │
#               ┌──────────────┴──────────────┐
#               │                             │
#               v                             v
#     ┌─────────────────┐           ┌─────────────────┐
#     │ Non-Preemptive  │           │   Preemptive    │
#     │                 │           │    (SRTF)       │
#     └─────────────────┘           └─────────────────┘
#               │                             │
#               v                             v
#     "Ek baar mila toh            "Beech mein bhi
#      koi nahi cheenk              cheena ja sakta
#      sakta CPU"                   hai CPU"
# </pre>
#
# **SRTF = Shortest Remaining Time First** (Preemptive SJF ka fancy naam!) 😎
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📝 **Example 1: Non-Preemptive SJF**
#
# ---
#
# ### **Problem Statement:**
#
# 4 processes hain, sab **same time pe arrive** hue (arrival time = 0):
#
# | Process | Burst Time (ms) |
# |---------|----------------|
# | P1 | 6 |
# | P2 | 8 |
# | P3 | 7 |
# | P4 | 3 |
#
# **Task:** Gantt Chart banao aur Average Waiting Time nikalo!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🧠 **Step-by-Step Solution:**
#
# ---
#
# **Step 1: Burst Times ko sort karo (Chhote se bade):**
#
# ```json
# P4(3) < P1(6) < P3(7) < P2(8)
# ```
#
# **Ye order mein CPU milega!** 📋
#
# ---
#
# **Step 2: Gantt Chart banao:**
#
# <pre style="background-color: #0d1117; padding: 15px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌───────┬───────────────┬─────────────────┬───────────────────┐
# │  P4   │      P1       │       P3        │        P2         │
# │ (3ms) │    (6ms)      │     (7ms)       │      (8ms)        │
# └───────┴───────────────┴─────────────────┴───────────────────┘
# 0       3               9                 16                  24
# </pre>
#
# ---
#
# **Step 3: Waiting Time Calculate karo:**
#
# *(Waiting Time = Jab CPU mila - Jab aaya)*
#
# Sab same time (0) pe aaye, toh:
#
# | Process | CPU Mila At | Waiting Time |
# |---------|-------------|-------------|
# | P4 | 0 | **0 ms** |
# | P1 | 3 | **3 ms** |
# | P3 | 9 | **9 ms** |
# | P2 | 16 | **16 ms** |
#
# ---
#
# **Step 4: Average Waiting Time:**
#
# ```json
# Average = (0 + 3 + 9 + 16) / 4 = 28/4 = 7 ms ✅
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🆚 **SJF vs FCFS Comparison:**
#
# ---
#
# Same processes ke liye:
#
# | Algorithm | Average Waiting Time |
# |-----------|---------------------|
# | **SJF** | **7 ms** ✅ |
# | **FCFS** | **10.25 ms** ❌ |
#
# **SJF wins!** 🏆
#
# **Kyun?** Chhote processes ko pehle karo → unka wait kam → overall average kam!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #a371f7;">
#
# # 📝 **Example 2: Preemptive SJF (SRTF)**
#
# ---
#
# ### **Ab thoda spicy! 🌶️**
#
# ### **Problem Statement:**
#
# 4 processes hain, **ALAG-ALAG time pe arrive** hue:
#
# | Process | Arrival Time | Burst Time (ms) |
# |---------|-------------|----------------|
# | P1 | 0 | 8 |
# | P2 | 1 | 4 |
# | P3 | 2 | 9 |
# | P4 | 3 | 5 |
#
# **Task:** Preemptive SJF use karke Gantt Chart banao aur Average Waiting Time nikalo!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🧠 **Step-by-Step Solution (Dhyan se padhna!):**
#
# ---
#
# **Preemptive mein har baar check karo:** *"Naya process aaya hai kya? Uska burst time current se kam hai kya?"*
#
# ---
#
# **⏱️ Time = 0:**
# - Sirf P1 hai (Burst = 8)
# - P1 ko CPU do! ✅
#
# **⏱️ Time = 1:**
# - P2 arrive hua (Burst = 4)
# - P1 ka remaining = 8-1 = **7**
# - P2 ka burst = **4**
# - **4 < 7? YES!** → P1 ko hatao, P2 ko do! 🔄
#
# **⏱️ Time = 2:**
# - P3 arrive hua (Burst = 9)
# - P2 ka remaining = 4-1 = **3**
# - **9 > 3?** → P2 continue karega, P3 wait karega!
#
# **⏱️ Time = 3:**
# - P4 arrive hua (Burst = 5)
# - P2 ka remaining = 3-1 = **2**
# - **5 > 2?** → P2 continue karega!
#
# **⏱️ Time = 5:**
# - P2 khatam! 🎉
# - Ab kaun hai? P1(7), P3(9), P4(5)
# - **P4 sabse chhota (5)** → P4 ko do!
#
# **⏱️ Time = 10:**
# - P4 khatam! 🎉
# - Ab kaun hai? P1(7), P3(9)
# - **P1 chhota (7)** → P1 ko do!
#
# **⏱️ Time = 17:**
# - P1 khatam! 🎉
# - Sirf P3 bacha → P3 ko do!
#
# **⏱️ Time = 26:**
# - P3 khatam! Sab ho gaya! ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 📊 **Gantt Chart:**
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────┬─────────────┬───────────────┬─────────────────┬───────────────────┐
# │ P1  │     P2      │      P4       │       P1        │        P3         │
# │(1ms)│   (4ms)     │    (5ms)      │     (7ms)       │      (9ms)        │
# └─────┴─────────────┴───────────────┴─────────────────┴───────────────────┘
# 0     1             5               10                17                  26
#
#       ^
#       |
#   P1 preempt hua!
#   (P2 chhota tha)
# </pre>
#
# **Notice karo:** P1 do baar aaya! Pehle 0-1, phir 10-17! 🔄
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #f85149;">
#
# ### 📐 **Waiting Time Formula (Preemptive ke liye IMPORTANT!):**
#
# ---
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 20px; color: #f0883e;">
#
# **Waiting Time = (Total Waiting Time) - (Previously Executed Time) - (Arrival Time)**
#
# </div>
#
# ---
#
# **Kyun ye formula?**
#
# Preemptive mein ek process **multiple times** CPU le sakta hai!
#
# Toh sirf "CPU kab mila" dekhna enough nahi hai... Jo pehle execute kar chuka, wo minus karo! ➖
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔢 **Waiting Time Calculation:**
#
# ---
#
# **For P1:**
# - Last time CPU mila: 10
#   >(As last as possible block dhundho P1 ka.Hame usi block me maujood P1 ka aarival time batana hai.Aur yahi hoga hamara Total waiting time)
# - Pehle kitna execute kiya: 1 (from 0-1)
#   >(Last block se pahle dekho ki kitni bar wo tukdo me execute ho chuka hai. Aur iska total time hi hota hai Previously Executed Time)
# - Arrival time: 0
#   >(Table me dekho likha hoga Arrival time, ki wo sabse pahle Ready Queue me kab aaya.)
# - **WT = 10 - 1 - 0 = 9 ms** ✅
# ---
# Given Table:
#
# | Process | Arrival Time | Burst Time (ms) |
# |---------|-------------|----------------|
# | P1 | 0 | 8 |
# | P2 | 1 | 4 |
# | P3 | 2 | 9 |
# | P4 | 3 | 5 |
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────┬─────────────┬───────────────┬─────────────────┬───────────────────┐
# │ P1  │     P2      │      P4       │       P1        │        P3         │
# │(1ms)│   (4ms)     │    (5ms)      │     (7ms)       │      (9ms)        │
# └─────┴─────────────┴───────────────┴─────────────────┴───────────────────┘
# 0     1             5               10                17                  26
#
#       ^
#       |
#   P1 preempt hua!
#   (P2 chhota tha)
# </pre>
# ---
#
# **For P2:**
# - CPU mila: 1
# - Pehle execute: 0 (first time hai)
# - Arrival time: 1
# - **WT = 1 - 0 - 1 = 0 ms** ✅
#
# *(Matlab P2 ko wait hi nahi karna pada! Aate hi CPU mil gaya because it preempted P1!)* 🎉
#
# ---
#
# **For P3:**
# - CPU mila: 17
# - Pehle execute: 0
# - Arrival time: 2
# - **WT = 17 - 0 - 2 = 15 ms** ✅
#
# ---
#
# **For P4:**
# - CPU mila: 5
# - Pehle execute: 0
# - Arrival time: 3
# - **WT = 5 - 0 - 3 = 2 ms** ✅
#
# ---
#
# ### **Average Waiting Time:**
#
# ```json
# Average = (9 + 0 + 15 + 2) / 4 = 26/4 = 6.5 ms ✅
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 💡 **Key Insight - Preemptive SJF = SRTF**
#
# ---
#
# **Preemptive SJF** ko **SRTF (Shortest Remaining Time First)** bhi bolte hain!
#
# **Kyun?** 🤔
#
# Kyunki har baar decide karte waqt hum dekh rahe hain:
#
# > "Kiska **REMAINING** time sabse kam hai?"
#
# Agar koi already execute ho raha hai, toh uska remaining kam ho gaya hai... So actual comparison remaining time se hoti hai! 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #f85149;">
#
# # ⚠️ **Disadvantages of SJF - Sab Achha Nahi Hai Bhai!**
#
# ---
#
# ### **🔴 Problem #1: "Bhai, Next CPU Burst Pata Kaise Chalega?"**
#
# Ye sabse badi problem hai! 😰
#
# SJF bolti hai: *"Jiska next CPU burst chhota, usse pehle"*
#
# But bhai... **Next CPU burst kaise pata chalega?** Hum future toh dekh nahi sakte! 🔮
#
# ```bash
# Process: "Main aane wala hoon!"
# OS: "Kitna time lagega tujhe?"
# Process: "Bhai mujhe khud nahi pata!" 😅
# ```
#
# **Reality:** Practically, we **CANNOT** know the exact length of next CPU burst!
#
# ---
#
# ### **🔴 Problem #2: Short-term Scheduling mein Use Nahi Ho Sakta!**
#
# SJF is **theoretically optimal** (minimum average waiting time deta hai)...
#
# But **practically implement nahi ho sakta** at CPU scheduling level! 💔
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ## 🩹 **Solution: Approximation - Andaaza Lagao!**
#
# ---
#
# Exact nahi pata? **Andaaza lagao!** 🎯
#
# ### **Approach:**
#
# > *"Agar pichle CPU bursts dekh liye, toh next burst ka idea lag jayega!"*
#
# **Example:**
# - Process ne pehle 5ms ka burst liya
# - Phir 6ms ka liya
# - Phir 4ms ka liya
# - **Prediction:** Next burst bhi around 4-6ms hoga! 📊
#
# ---
#
# ### **Technical Term:** *Exponential Averaging*
#
# ```json
# τ(n+1) = α × t(n) + (1-α) × τ(n)
#
# Where:
# τ(n+1) = predicted next burst
# t(n) = actual last burst
# τ(n) = previous prediction
# α = weightage (0 to 1)
# ```
#
# **Simple Terms mein:** Past history se future predict karo! 📈
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📋 **Quick Comparison Table - SJF Summary**
#
# ---
#
# | Feature | Non-Preemptive SJF | Preemptive SJF (SRTF) |
# |---------|-------------------|----------------------|
# | **Preemption** | ❌ Nahi | ✅ Haan |
# | **Decision Time** | Sirf jab CPU free ho | Har naya process aaye tab |
# | **Complexity** | Simple | Thoda Complex |
# | **Waiting Time** | Good | Better |
# | **Context Switches** | Less | More |
# | **Another Name** | SJN (Shortest Job Next) | SRTF (Shortest Remaining Time First) |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ## 🎯 **SJF vs FCFS - Final Showdown:**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────────────────────────────────────────────────────────────┐
# │                    FCFS vs SJF                              │
# ├─────────────────────────────────────────────────────────────┤
# │                                                             │
# │   FCFS:  "Jo pehle aaya wo pehle!"                          │
# │          - Simple hai                                       │
# │          - Fair lagta hai                                   │
# │          - But average waiting time ZYADA                   │
# │                                                             │
# │   SJF:   "Jo chhota hai wo pehle!"                          │
# │          - Optimal average waiting time                     │
# │          - Chhote processes khush                           │
# │          - But burst time predict karna mushkil             │
# │                                                             │
# │   WINNER: SJF (theoretically) but FCFS (practically)        │
# │                                                             │
# └─────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎬 **Wrap-Up - Moral of the Story!**
#
# ---
#
# ### **One-Line Summary:**
#
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; font-size: 22px; color: #3fb950; border: 1px solid #3fb950;">
#
# **"Chhote kaam pehle karo, toh sabka wait kam hoga!"** 🚀
#
# </div>
#
# ---
#
# ### **Key Takeaways:**
#
# ✅ SJF = Shortest (Next CPU) Burst wale ko pehle CPU do
#
# ✅ Tie hone pe FCFS use karo
#
# ✅ Non-Preemptive = Ek baar mila toh mila
#
# ✅ Preemptive (SRTF) = Chhota aaya toh bade ko hatao
#
# ✅ Optimal hai but practical nahi (burst time pata nahi chalta)
#
# ✅ Solution: Past history se predict karo!
#
# ---
#
# ### **Exam Tip:** 📝
#
# Preemptive SJF problems mein **remaining time** track karte rehna har step pe!
#
# ---
#
# <p style="text-align: center; color: #8b949e; font-size: 16px;">
# <strong>Bas yehi tha aaj ka lecture! Questions ho toh poochho, warna next topic pe chalte hain! ✌️</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #8b949e; text-align: center; margin-top: 20px;">
#
# ---
#
# *Made with ❤️ by Bhai - Your Desi CS Tutor*
#
# *"Padhai boring nahi honi chahiye!"* 🎓
#
# ---
#
# </div>
