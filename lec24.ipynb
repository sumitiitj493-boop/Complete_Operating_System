# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #a371f7;">
#
# # 👑 **Priority Scheduling Algorithm**
# ## *Jiska Priority Zyada, Uska Pehle Kaam!*
#
# <p style="color: #8b949e; font-size: 16px;">Operating Systems - CPU Scheduling Series | Bhai Style Explanation</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #30363d;">
#
# ## 🎬 **The Hook - Kahani Shuru!**
#
# ---
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture mein hum fodne wale hain Priority Scheduling Algorithm!** 💥
#
# Bhai, kabhi socha hai ki **Hospital Emergency** mein kya hota hai? 🏥
#
# Imagine karo:
# - Ek banda aaya jisko **halka sa sar dard** hai (Normal case)
# - Phir ek aaya jisko **fracture** hua hai (Serious)
# - Phir ek aaya jisko **heart attack** aa raha hai (Critical!)
#
# Ab doctor kaun dekhega pehle? **Heart attack wala na!** Kyunki uski **PRIORITY** sabse zyada hai! 🚨
#
# Fir fracture wala, phir sar dard wala...
#
# **Yahi hai Priority Scheduling ka asli funda!** Jis process ki priority zyada, usse CPU pehle milega! 👑
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ⏪ **Flashback Zone - "Yaad Hai Bhai?"**
#
# ---
#
# Ruko bhai! Aage badhne se pehle kuch **basics yaad karte hain**... Professor ne assume kiya ki sab yaad hai, but tension nahi - fatafat revise kar lete hain! 📚
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔄 **Yaad Hai? #1: FCFS & SJF Kya The?**
#
# ---
#
# **FCFS (First Come First Serve):**
# - Jo pehle aaya, usse pehle CPU milega
# - Bank ki line jaisa - Token 1 pehle, Token 2 baad mein! 🏦
#
# **SJF (Shortest Job First):**
# - Jiska kaam chhota hai, usse pehle CPU
# - Sabzi wala - "Bhaiya sirf dhaniya dena" wale ko pehle de deta hai! 🥬
#
# **Fun Fact:** SJF bhi ek tarah ki **Priority Scheduling** hi hai! (Baad mein samjhayenge) 🤯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔄 **Yaad Hai? #2: Preemptive vs Non-Preemptive?**
#
# ---
#
# | Type | Matlab | Example |
# |------|--------|--------|
# | **Non-Preemptive** | Ek baar CPU mila toh koi cheenk nahi sakta | Bathroom mein ghuse toh bahar aao tab tak wait! 🚽 |
# | **Preemptive** | Beech mein bhi CPU cheena ja sakta hai | Boss ka call aaye toh sab chhodo, boss se baat karo! 📞 |
#
# **Priority Scheduling dono ho sakti hai!** 😎
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🔄 **Yaad Hai? #3: Burst Time & Waiting Time?**
#
# ---
#
# **Burst Time:** Process ko CPU kitni der chahiye (Execution time)
#
# **Waiting Time:** Process ko CPU milne se pehle kitna wait karna pada
#
# ```json
# Waiting Time = CPU milne ka time - Arrival time
# ```
#
# **Gantt Chart:** Timeline diagram jo dikhata hai kaun kab execute hua! 📊
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ✅ **Basics Clear! Ab Asli Masala!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #a371f7;">
#
# # 🎯 **Priority Scheduling - The Main Concept**
#
# ---
#
# ### **Definition (Seedha Point!):**
#
# > **Har process ko ek PRIORITY number diya jata hai. Jis process ki priority HIGHEST hai, usse CPU PEHLE milta hai!**
#
# ---
#
# ### **🎬 Real Life Analogy - Airport Security Check:**
#
# Airport pe dekho:
#
# - **First Class Passengers** → Priority 1 (Sabse pehle) ✈️
# - **Business Class** → Priority 2 💼
# - **Economy Class** → Priority 3 🎒
# - **Standby Passengers** → Priority 4 (Sabse baad mein) 😅
#
# Chahe Economy wala 2 ghante pehle aaya ho, First Class wala **directly andar**! Kyunki **Priority matters!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🔢 **Priority Number Ka Funda:**
#
# ---
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; border: 1px solid #f85149;">
#
# **⚠️ Important:** Priority number kaise kaam karta hai, ye **book/system dependent** hai!
#
# | Convention | Highest Priority | Lowest Priority |
# |------------|-----------------|----------------|
# | **Type 1** | 1 (Chhota number = High) | 127 |
# | **Type 2** | 127 (Bada number = High) | 1 |
#
# </div>
#
# **Hum Type 1 follow karenge:** Chhota number = Higher Priority! 🎯
#
# ```json
# Priority 1 > Priority 2 > Priority 3 > ... > Priority N
# (Highest)                              (Lowest)
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 💡 **Mind = Blown! SJF Bhi Priority Scheduling Hai!**
#
# ---
#
# Bhai, ye sunke tere dimaag ki batti jal jayegi! 💡
#
# **SJF is actually Priority Scheduling** where:
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; text-align: center; font-size: 18px; color: #3fb950;">
#
# **Priority = Inverse of CPU Burst Time**
#
# </div>
#
# **Matlab:**
# - **Chhota Burst Time** → **Higher Priority** (Pehle CPU milega)
# - **Bada Burst Time** → **Lower Priority** (Baad mein milega)
#
# Toh technically, SJF mein burst time hi priority decide karta hai! 🤯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🤝 **Tie-Breaking Rule - Agar Priority Same Ho?**
#
# ---
#
# Socho do processes hain:
# - P1: Priority = 2
# - P2: Priority = 2
#
# **Dono ki priority same! Ab kisko pehle dein?** 🤔
#
# **Answer:** Jab priority same ho, toh **FCFS use karo!**
#
# Matlab jo pehle aaya, usse pehle CPU do!
#
# **Simple Rule:** Priority tie? → FCFS apply! ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ## 📊 **Priority Scheduling Ke Do Avatars!**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #3fb950; white-space: pre; font-family: monospace; overflow-x: auto;">
#                   ┌────────────────────────┐
#                   │  Priority Scheduling   │
#                   └───────────┬────────────┘
#                               │
#             ┌─────────────────┴─────────────────┐
#             │                                   │
#             v                                   v
#   ┌──────────────────┐               ┌──────────────────┐
#   │  Non-Preemptive  │               │    Preemptive    │
#   └──────────────────┘               └──────────────────┘
#             │                                   │
#             v                                   v
#   "High priority aaya?"              "High priority aaya?"
#   "Queue mein aage rakho,"           "Current ko hatao,"
#   "current finish hone do"           "naye ko CPU do!"
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔵 **Preemptive Priority Scheduling:**
#
# ---
#
# **Scene:** P1 (Priority 3) execute ho raha hai... tabhi P2 aata hai (Priority 1)!
#
# **Kya hoga?**
#
# ```json
# P2 ki priority (1) > P1 ki priority (3)
#          ↓
# P1 ko TURANT hatao! (Preempt!)
#          ↓
# P2 ko CPU do!
# ```
#
# **Real Life:** Boss meeting mein busy hai (Priority Low task), PM ka call aata hai (Priority High) → Meeting pause, call attend! 📞
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🟠 **Non-Preemptive Priority Scheduling:**
#
# ---
#
# **Scene:** P1 (Priority 3) execute ho raha hai... tabhi P2 aata hai (Priority 1)!
#
# **Kya hoga?**
#
# ```json
# P2 ki priority (1) > P1 ki priority (3)
#          ↓
# BUT... P1 ko disturb NAHI karenge!
#          ↓
# P2 ko Ready Queue ke HEAD pe rakho
#          ↓
# P1 khatam hote hi P2 ko CPU!
# ```
#
# **Real Life:** Doctor surgery mein hai, VIP patient aaya → Surgery complete hone do, phir VIP ka dekho! 🏥
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📝 **Example: Non-Preemptive Priority Scheduling**
#
# ---
#
# ### **Problem Statement:**
#
# 5 processes hain, sab **same time (0) pe arrive** hue, order: P1, P2, P3, P4, P5
#
# | Process | Burst Time (ms) | Priority |
# |---------|----------------|----------|
# | P1 | 10 | 3 |
# | P2 | 1 | 1 |
# | P3 | 2 | 4 |
# | P4 | 1 | 5 |
# | P5 | 5 | 2 |
#
# **Note:** Lower number = Higher Priority (1 sabse high, 5 sabse low)
#
# **Task:** Gantt Chart banao aur Average Waiting Time nikalo!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🧠 **Step 1: Priority Order Samjho**
#
# ---
#
# **Processes ko priority ke hisaab se sort karo:**
#
# ```json
# P2 (Priority 1) → P5 (Priority 2) → P1 (Priority 3) → P3 (Priority 4) → P4 (Priority 5)
#    (Highest)                                                            (Lowest)
# ```
#
# **Isi order mein CPU milega!** 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🧠 **Step 2: Gantt Chart Banao**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────┬───────────────┬─────────────────────────────┬───────┬─────┐
# │ P2  │      P5       │             P1              │  P3   │ P4  │
# │(1ms)│    (5ms)      │          (10ms)             │ (2ms) │(1ms)│
# └─────┴───────────────┴─────────────────────────────┴───────┴─────┘
# 0     1               6                             16      18    19
#       ^
#       |
#   Priority 1 sabse pehle!
# </pre>
#
# **Breakdown:**
# - **P2** (Priority 1): 0 → 1 (1 ms)
# - **P5** (Priority 2): 1 → 6 (5 ms)
# - **P1** (Priority 3): 6 → 16 (10 ms)
# - **P3** (Priority 4): 16 → 18 (2 ms)
# - **P4** (Priority 5): 18 → 19 (1 ms)
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🧠 **Step 3: Waiting Time Calculate Karo**
#
# ---
#
# Sab processes arrival time = 0 pe aaye, toh:
#
# **Waiting Time = Jab CPU mila - Arrival Time (0)**
#
# | Process | CPU Mila At | Waiting Time |
# |---------|-------------|-------------|
# | P1 | 6 | **6 ms** |
# | P2 | 0 | **0 ms** |
# | P3 | 16 | **16 ms** |
# | P4 | 18 | **18 ms** |
# | P5 | 1 | **1 ms** |
#
# ---
#
# ### **Average Waiting Time:**
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950;">
#
# **Average WT = (6 + 0 + 16 + 18 + 1) / 5 = 41/5 = 8.2 ms**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #f85149;">
#
# # ⚠️ **Problem: Starvation (Bhookh se Marna!)**
#
# ---
#
# ### **🚨 The Big Issue:**
#
# Bhai, yahan ek **bahut bada problem** hai!
#
# **Scenario Samjho:**
#
# - Ek **low priority process** (P-Low) queue mein wait kar raha hai
# - Baar baar **high priority processes** aate rehte hain
# - High priority wale CPU lete rehte hain...
# - **P-Low bas wait karta reh jata hai... FOREVER!** 😭
#
# ---
#
# ### **📺 Real Life Example:**
#
# Imagine hospital emergency:
#
# ```json
# Time 0:  Sar dard wala aaya (Low Priority) → Wait kar bhai
# Time 1:  Heart attack case aaya → Usko dekho pehle!
# Time 2:  Accident case aaya → Usko dekho!
# Time 3:  Another heart attack → Usko dekho!
# ...
# Time ∞:  Sar dard wala still waiting... 💀
# ```
#
# **Ye hai STARVATION / INDEFINITE BLOCKING!** 🥺
#
# Low priority process kabhi CPU nahi le paata... **bhookha mar jata hai!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### 📖 **Technical Definition:**
#
# ---
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; border-left: 4px solid #f85149;">
#
# **Starvation (Indefinite Blocking):**
#
# A situation where a **low-priority process** waits **indefinitely** for the CPU because high-priority processes keep arriving and getting CPU access.
#
# </div>
#
# **In Simple Words:** Bechara low priority process queue mein sadta rehta hai! 😢
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# # ✅ **Solution: AGING (Budhapa ka Fayda!)**
#
# ---
#
# ### **🧓 The Aging Technique:**
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950; border: 1px solid #3fb950;">
#
# **Jitna zyada wait karega, utni uski PRIORITY badh jayegi!**
#
# </div>
#
# ---
#
# ### **📺 Real Life Analogy - Customer Complaint:**
#
# Imagine Flipkart customer care:
#
# ```json
# Day 1:  Complaint registered → Priority: Low
# Day 3:  Customer waiting → Priority: Medium
# Day 7:  Still waiting → Priority: High
# Day 14: Bahut zyada wait → Priority: URGENT! 🚨
# ```
#
# Jitna zyada wait, utna priority **automatically increase!**
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔢 **Aging - Technical Example:**
#
# ---
#
# **System Setup:**
# - Priority Range: **0 (Highest)** to **127 (Lowest)**
# - Aging Rule: Har **15 minutes** mein priority **+1 increase** karo
#
# ---
#
# **Scenario:**
#
# P-Low (Priority 127 = Sabse kam) queue mein aata hai...
#
# <pre style="background-color: #0d1117; padding: 15px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# Time 0 min:     Priority = 127 (Lowest)
# Time 15 min:    Priority = 126
# Time 30 min:    Priority = 125
# Time 45 min:    Priority = 124
# ...
# After ~32 hours: Priority = 0 (HIGHEST!)
# </pre>
#
# **Eventually, even lowest priority process becomes HIGHEST priority!** 🎉
#
# Ab usse CPU milna **guaranteed** hai!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 📝 **Aging - Formal Definition:**
#
# ---
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
#
# **Aging:**
#
# A technique of **gradually increasing the priority** of processes that have been **waiting in the system for a long time**.
#
# </div>
#
# **Result:** No process will **starve forever!** ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #a371f7;">
#
# ## 📋 **Quick Comparison Table**
#
# ---
#
# | Feature | FCFS | SJF | Priority |
# |---------|------|-----|----------|
# | **Basis** | Arrival Time | Burst Time | Priority Number |
# | **Preemptive?** | No | Yes/No | Yes/No |
# | **Starvation?** | No | Possible | Yes |
# | **Solution** | N/A | Aging | **Aging** |
# | **Optimal?** | No | Yes (for WT) | Depends |
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ## 🔑 **Key Points Summary:**
#
# ---
#
# <pre style="background-color: #0d1117; padding: 20px; border-radius: 8px; color: #f0883e; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌────────────────────────────────────────────────────────────────┐
# │              PRIORITY SCHEDULING - KEY POINTS                  │
# ├────────────────────────────────────────────────────────────────┤
# │                                                                │
# │  1. Har process ko ek PRIORITY assign hoti hai                 │
# │                                                                │
# │  2. Highest priority = CPU pehle                               │
# │                                                                │
# │  3. Same priority? --> FCFS use karo                           │
# │                                                                │
# │  4. SJF bhi Priority Scheduling hai (Priority = 1/Burst)       │
# │                                                                │
# │  5. Preemptive: High priority aaye --> Current hatao           │
# │                                                                │
# │  6. Non-Preemptive: High priority aaye --> Queue mein rakho    │
# │                                                                │
# │  7. Problem: STARVATION (Low priority kabhi execute na ho)     │
# │                                                                │
# │  8. Solution: AGING (Wait karte karte priority badhao)         │
# │                                                                │
# └────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎬 **Wrap-Up - Moral of the Story!**
#
# ---
#
# ### **One-Line Summary:**
#
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; font-size: 22px; color: #3fb950; border: 1px solid #3fb950;">
#
# **"VIP ko pehle entry, but itna wait karwao ki non-VIP bhi VIP ban jaye!"** 👑
#
# </div>
#
# ---
#
# ### **Key Takeaways:**
#
# ✅ **Priority Scheduling** = Jis process ki priority zyada, usse CPU pehle
#
# ✅ **Tie?** → FCFS use karo (Jo pehle aaya wo pehle)
#
# ✅ **SJF = Priority Scheduling** (where Priority = 1/Burst Time)
#
# ✅ **Preemptive:** Higher priority aaya? Current ko turant hatao!
#
# ✅ **Non-Preemptive:** Higher priority aaya? Queue mein aage rakho, current finish hone do
#
# ✅ **Problem:** Starvation (Low priority process bhookha mar sakta hai)
#
# ✅ **Solution:** Aging (Wait karte karte priority automatically badhti hai)
#
# ---
#
# ### **Exam Tip:** 📝
#
# Priority number ka convention **question mein check karo** - chhota high hai ya bada high hai!
#
# ---
#
# <p style="text-align: center; color: #8b949e; font-size: 16px;">
# <strong>Bas yehi tha aaj ka lecture! Ab Priority Scheduling clear hai na? Next lecture mein problems solve karenge! ✌️</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #8b949e; text-align: center; margin-top: 20px;">
#
# ---
#
# *Made with ❤️ by Bhai - Your Desi OS Tutor*
#
# *"Priority matter karta hai, but aging se sabka number aata hai!"* 🎓
#
# ---
#
# </div>
