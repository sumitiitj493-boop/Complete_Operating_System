# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #a371f7;">
#
# # 🎯 **Priority Scheduling - GATE Solved Problems**
# ## *Preemptive & Non-Preemptive Dono Ka Full Package!*
#
# <p style="color: #8b949e; font-size: 16px;">GATE CS 2017 + Practice Problem | Bhai Style GATE Prep 🔥</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #30363d;">
#
# ## 🎬 **The Hook - Aaj Ka Mission!**
#
# ---
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture mein hum GATE level ke priority scheduling problems solve karenge!** 💥
#
# Dekho bhai, Priority Scheduling samajhna alag baat hai... aur **exam mein time pressure mein solve karna** bilkul alag game hai! 🎮
#
# Aaj hum **DO problems** solve karenge:
#
# | Problem | Type | Kya Nikalna Hai |
# |---------|------|----------------|
# | **GATE 2017** | **Preemptive** Priority | Average Waiting Time |
# | **Practice** | **Non-Preemptive** Priority | Avg WT + Avg TAT |
#
# **Dono types cover!** Exam mein kuch bhi aaye, ready rahoge! 🚀
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ⏪ **Flashback Zone - "Yaad Hai Bhai?"**
#
# ---
#
# Ruko bhai! Problems solve karne se pehle kuch **basics quick revise** kar lete hain... GATE examiner assume karta hai ki sab yaad hai! 📚
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔄 **Yaad Hai? #1: Priority Scheduling Ka Funda**
#
# ---
#
# **Simple Rule:** Jis process ki **PRIORITY zyada**, usse **CPU pehle!** 👑
#
# **⚠️ IMPORTANT - Priority Number Convention:**
#
# | Convention | Highest Priority | Example |
# |------------|-----------------|--------|
# | **Type 1** | Lower number = High | 0 > 1 > 2 > 3 |
# | **Type 2** | Higher number = High | 5 > 4 > 3 > 2 |
#
# **Exam Tip:** Question CAREFULLY padho - kaun sa convention use ho raha hai! 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔄 **Yaad Hai? #2: Preemptive vs Non-Preemptive**
#
# ---
#
# | Type | Kya Hota Hai | Real Life |
# |------|-------------|----------|
# | **Preemptive** | Higher priority aaya? Current ko **turant hatao!** | Boss ka urgent call = meeting chhodo! 📞 |
# | **Non-Preemptive** | Higher priority aaya? **Queue mein rakho**, current finish hone do | Surgery chal rahi hai, VIP wait karega! 🏥 |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🔄 **Yaad Hai? #3: Important Formulas**
#
# ---
#
# **📌 Preemptive ke liye Waiting Time:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 16px; color: #58a6ff;">
#
# **WT = (Last time CPU mila) - (Pehle execute kiya tha) - (Arrival Time)**
#
# </div>
#
# ---
#
# **📌 Non-Preemptive ke liye:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 16px; color: #3fb950;">
#
# **Turnaround Time (TAT) = Completion Time - Arrival Time**
#
# **Waiting Time (WT) = TAT - Burst Time**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🔄 **Yaad Hai? #4: Tie-Breaking Rule**
#
# ---
#
# **Agar do processes ki SAME priority ho?** 🤔
#
# **Answer:** **FCFS use karo!** Jo pehle aaya, usse pehle CPU!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ✅ **Basics Clear! Ab Problem 1 Solve Karte Hain!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #f0883e;">
#
# # 📝 **Problem 1: GATE CS 2017 - Preemptive Priority**
#
# ---
#
# ### **Question:**
#
# Consider the set of processes with arrival time (ms), CPU burst time (ms), and priority. **0 is the highest priority.** None of the processes have I/O burst time.
#
# | Process | Arrival Time | Burst Time | Priority |
# |---------|-------------|------------|----------|
# | P1 | 0 | 11 | 2 |
# | P2 | 5 | 28 | 0 |
# | P3 | 12 | 2 | 3 |
# | P4 | 2 | 10 | 1 |
# | P5 | 9 | 16 | 4 |
#
# **The average waiting time (in ms) using preemptive priority scheduling is ___?**
#
# **Options:** (A) 29 (B) 30 (C) 31 (D) 32
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### ⚠️ **Dhyan Se Padho Bhai!**
#
# - **0 = Highest Priority** (Lower number = Higher priority)
# - **Preemptive** hai - matlab higher priority aaye toh current hatao!
# - Options bahut close hain (29, 30, 31, 32) - ek bhi galti = wrong answer! 😰
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ## 🧠 **Solution - Step by Step!**
#
# ---
#
# ### **Step 1: Priority Order Samjho (Lower = Higher)**
#
# ```
# P2 (0) > P4 (1) > P1 (2) > P3 (3) > P5 (4)
# (Highest)                        (Lowest)
# ```
#
# **P2 sabse VIP hai!** 👑
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **Step 2: Gantt Chart Banao (Preemptive Style!)** 📊
#
# ---
#
# **🕐 Time = 0:**
# - Sirf **P1** hai (Priority = 2, Burst = 11)
# - P1 ko CPU do! ✅
#
# ---
#
# **🕐 Time = 2:**
# - **P4 arrives** (Priority = 1, Burst = 10)
# - P1 ka priority = 2, P4 ka priority = 1
# - **1 < 2?** ✅ P4 ki priority ZYADA hai!
# - **P1 preempted! P4 gets CPU!** 🔄
# - P1 ne execute kiya: 2ms, Remaining: 11-2 = **9ms**
#
# ---
#
# **🕐 Time = 5:**
# - **P2 arrives** (Priority = 0, Burst = 28) 🚨 **HIGHEST PRIORITY!**
# - P4 ka priority = 1, P2 ka priority = 0
# - **0 < 1?** ✅ P2 ki priority SABSE ZYADA!
# - **P4 preempted! P2 gets CPU!** 🔄
# - P4 ne execute kiya: 3ms (from 2 to 5), Remaining: 10-3 = **7ms**
#
# ---
#
# **🕐 Time = 9:**
# - **P5 arrives** (Priority = 4)
# - P2 executing (Priority = 0)
# - **4 > 0?** P2 ki priority zyada hai!
# - **P2 continues!** ✅
#
# ---
#
# **🕐 Time = 12:**
# - **P3 arrives** (Priority = 3)
# - P2 still executing (Priority = 0)
# - **3 > 0?** P2 ki priority zyada hai!
# - **P2 continues!** ✅
#
# ---
#
# **🕐 Time = 33:**
# - **P2 completes!** 🎉 (5 + 28 = 33)
# - Remaining: P1(9, pri=2), P3(2, pri=3), P4(7, pri=1), P5(16, pri=4)
# - **Highest priority?** P4 (priority = 1)
# - **P4 gets CPU!**
#
# ---
#
# **🕐 Time = 40:**
# - **P4 completes!** 🎉 (33 + 7 = 40)
# - Remaining: P1(9, pri=2), P3(2, pri=3), P5(16, pri=4)
# - **Highest priority?** P1 (priority = 2)
# - **P1 gets CPU!**
#
# ---
#
# **🕐 Time = 49:**
# - **P1 completes!** 🎉 (40 + 9 = 49)
# - Remaining: P3(2, pri=3), P5(16, pri=4)
# - **P3 gets CPU!** (priority 3 > 4)
#
# ---
#
# **🕐 Time = 51:**
# - **P3 completes!** 🎉 (49 + 2 = 51)
# - Only P5 left → **P5 gets CPU!**
#
# ---
#
# **🕐 Time = 67:**
# - **P5 completes!** 🎉 (51 + 16 = 67)
# - **SAB KHATAM!** ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### **📊 Final Gantt Chart:**
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────┬─────────┬────────────────────────────────────────────┬─────────────────┬───────────────────┬───────┬─────────────────────────────┐
# │ P1  │   P4    │                    P2                      │       P4        │        P1         │  P3   │            P5               │
# │(2ms)│  (3ms)  │                 (28ms)                     │     (7ms)       │      (9ms)        │ (2ms) │          (16ms)             │
# └─────┴─────────┴────────────────────────────────────────────┴─────────────────┴───────────────────┴───────┴─────────────────────────────┘
# 0     2         5                                            33                40                  49      51                            67
#       ^         ^
#       |         |
#   P1 preempt  P4 preempt
#   (P4 aaya)   (P2 aaya - HIGHEST!)
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### **Step 3: Waiting Time Calculate Karo (Preemptive Formula!)** ⏱️
#
# ---
#
# **Formula:** `WT = (Last CPU mila) - (Pehle execute kiya) - (Arrival Time)`
#
# ---
#
# **For P1:**
# - Last time CPU mila: **40**
# - Pehle execute kiya: **2** (from 0-2)
# - Arrival time: **0**
# - **WT = 40 - 2 - 0 = 38 ms** ✅
#
# ---
#
# **For P2:**
# - CPU mila at: **5**
# - Pehle execute: **0** (first time)
# - Arrival time: **5**
# - **WT = 5 - 0 - 5 = 0 ms** ✅
#
# *(P2 = Highest priority, aate hi CPU mil gaya, koi preempt nahi kar saka!)* 👑
#
# ---
#
# **For P3:**
# - CPU mila at: **49**
# - Pehle execute: **0**
# - Arrival time: **12**
# - **WT = 49 - 0 - 12 = 37 ms** ✅
#
# ---
#
# **For P4:**
# - Last time CPU mila: **33**
# - Pehle execute kiya: **3** (from 2-5)
# - Arrival time: **2**
# - **WT = 33 - 3 - 2 = 28 ms** ✅
#
# ---
#
# **For P5:**
# - CPU mila at: **51**
# - Pehle execute: **0**
# - Arrival time: **9**
# - **WT = 51 - 0 - 9 = 42 ms** ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ### **Step 4: Average Waiting Time!** 🎯
#
# ---
#
# | Process | Waiting Time |
# |---------|-------------|
# | P1 | 38 ms |
# | P2 | 0 ms |
# | P3 | 37 ms |
# | P4 | 28 ms |
# | P5 | 42 ms |
#
# ---
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 22px; color: #3fb950;">
#
# **Average WT = (38 + 0 + 37 + 28 + 42) / 5 = 145/5 = 29 ms**
#
# </div>
#
# ---
#
# ### **✅ Answer: Option (A) 29 milliseconds!** 🎉
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #a371f7; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## 🔄 **Ab Problem 2 - Non-Preemptive Priority!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #a371f7;">
#
# # 📝 **Problem 2: Non-Preemptive Priority Scheduling**
#
# ---
#
# ### **Question:**
#
# Consider the set of processes. **Higher numbers represent higher priority.** Using **Non-Preemptive** Priority Scheduling, calculate Average Waiting Time and Average Turnaround Time.
#
# | Process | Arrival Time | Burst Time | Priority |
# |---------|-------------|------------|----------|
# | P1 | 0 | 4 | 2 |
# | P2 | 1 | 3 | 3 |
# | P3 | 2 | 1 | 4 |
# | P4 | 3 | 5 | 5 |
# | P5 | 4 | 2 | 5 |
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### ⚠️ **Key Differences from Problem 1:**
#
# 1. **Higher number = Higher Priority** (Ulta convention!)
# 2. **Non-Preemptive** - Koi disturb nahi karega executing process ko!
# 3. P4 & P5 dono ki **same priority (5)** - Tie-breaking needed! 🤝
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ## 🧠 **Solution - Step by Step!**
#
# ---
#
# ### **Step 1: Priority Order (Higher = Higher)**
#
# ```json
# P4 (5) = P5 (5) > P3 (4) > P2 (3) > P1 (2)
# (Highest)                        (Lowest)
# ```
#
# **P4 & P5 dono VIP hain! Tie-break = FCFS (jo pehle aaya)** 👑
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **Step 2: Gantt Chart Banao (Non-Preemptive Style!)** 📊
#
# ---
#
# **🕐 Time = 0:**
# - Sirf **P1** hai (Priority = 2, Burst = 4)
# - P1 ko CPU do! ✅
# - **Non-preemptive hai** - P1 complete hone tak koi disturb nahi karega!
#
# ---
#
# **During 0-4 (P1 executing):**
# - Time 1: P2 arrives (Priority 3)
# - Time 2: P3 arrives (Priority 4)
# - Time 3: P4 arrives (Priority 5)
# - Time 4: P5 arrives (Priority 5)
#
# **Sab wait kar rahe hain!** P1 disturb nahi hoga! 🛡️
#
# ---
#
# **🕐 Time = 4:**
# - **P1 completes!** 🎉
# - Ready Queue: P2(3), P3(4), P4(5), P5(5)
# - **Highest priority?** P4 & P5 (both = 5)
# - **Tie-break:** P4 arrived at 3, P5 arrived at 4
# - **P4 pehle aaya → P4 gets CPU!**
#
# ---
#
# **🕐 Time = 9:**
# - **P4 completes!** 🎉 (4 + 5 = 9)
# - Ready Queue: P2(3), P3(4), P5(5)
# - **Highest?** P5 (priority = 5)
# - **P5 gets CPU!**
#
# ---
#
# **🕐 Time = 11:**
# - **P5 completes!** 🎉 (9 + 2 = 11)
# - Ready Queue: P2(3), P3(4)
# - **Highest?** P3 (priority = 4)
# - **P3 gets CPU!**
#
# ---
#
# **🕐 Time = 12:**
# - **P3 completes!** 🎉 (11 + 1 = 12)
# - Only P2 left → **P2 gets CPU!**
#
# ---
#
# **🕐 Time = 15:**
# - **P2 completes!** 🎉 (12 + 3 = 15)
# - **SAB KHATAM!** ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### **📊 Final Gantt Chart:**
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌───────────────┬───────────────────┬───────────┬─────┬───────────┐
# │      P1       │        P4         │    P5     │ P3  │    P2     │
# │    (4ms)      │      (5ms)        │   (2ms)   │(1ms)│   (3ms)   │
# └───────────────┴───────────────────┴───────────┴─────┴───────────┘
# 0               4                   9           11    12          15
#
# Note: P4 & P5 same priority, but P4 pehle aaya (FCFS tie-break)
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### **Step 3: Turnaround Time & Waiting Time Calculate Karo!** ⏱️
#
# ---
#
# **Non-Preemptive Formulas:**
# - `TAT = Completion Time - Arrival Time`
# - `WT = TAT - Burst Time`
#
# ---
#
# | Process | Completion | Arrival | TAT | Burst | WT |
# |---------|-----------|---------|-----|-------|----|
# | P1 | 4 | 0 | 4-0 = **4** | 4 | 4-4 = **0** |
# | P2 | 15 | 1 | 15-1 = **14** | 3 | 14-3 = **11** |
# | P3 | 12 | 2 | 12-2 = **10** | 1 | 10-1 = **9** |
# | P4 | 9 | 3 | 9-3 = **6** | 5 | 6-5 = **1** |
# | P5 | 11 | 4 | 11-4 = **7** | 2 | 7-2 = **5** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ### **Step 4: Averages Calculate Karo!** 🎯
#
# ---
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950;">
#
# **Average TAT = (4 + 14 + 10 + 6 + 7) / 5 = 41/5 = 8.2 ms**
#
# **Average WT = (0 + 11 + 9 + 1 + 5) / 5 = 26/5 = 5.2 ms**
#
# </div>
#
# ---
#
# ### **✅ Final Answers:**
# - **Average Turnaround Time = 8.2 ms** 🎉
# - **Average Waiting Time = 5.2 ms** 🎉
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #f85149;">
#
# ## ⚠️ **Common Mistakes - Dhyan Rakhna Bhai!**
#
# ---
#
# ### **❌ Mistake 1: Priority Convention Confuse Karna**
#
# ```
# Problem 1: Lower number = Higher priority (0 > 1 > 2)
# Problem 2: Higher number = Higher priority (5 > 4 > 3)
# ```
# **Question CAREFULLY padho!** 📖
#
# ---
#
# ### **❌ Mistake 2: Preemptive mein "Previously Executed" bhoolna**
#
# P1 ne 2ms execute kiya, phir preempt hua, phir baad mein 9ms execute kiya.
#
# **WT = 40 - 2 - 0 = 38** (wo 2ms minus karna mat bhoolna!)
#
# ---
#
# ### **❌ Mistake 3: Tie-Breaking Rule Ignore Karna**
#
# Same priority? → **FCFS use karo!** (Jo pehle aaya wo pehle!)
#
# ---
#
# ### **❌ Mistake 4: Non-Preemptive mein process ko beech mein preempt karna**
#
# Non-Preemptive = **Ek baar CPU mila toh complete hone tak koi nahi cheenegaa!** 🛡️
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# ## 📋 **Quick Reference - Formula Cheat Sheet**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                  PRIORITY SCHEDULING FORMULAS                           │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  PREEMPTIVE WAITING TIME:                                               │
# │  WT = (Last CPU milne ka time) - (Pehle execute kiya) - (Arrival)       │
# │                                                                         │
# │  NON-PREEMPTIVE:                                                        │
# │  TAT = Completion Time - Arrival Time                                   │
# │  WT  = TAT - Burst Time                                                 │
# │                                                                         │
# │  TIE-BREAKING:                                                          │
# │  Same priority? --> FCFS (Jo pehle aaya, wo pehle!)                     │
# │                                                                         │
# │  AVERAGE:                                                               │
# │  Avg = Sum of all values / Number of processes                          │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎬 **Wrap-Up - Moral of the Story!**
#
# ---
#
# ### **One-Line Summary:**
#
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; font-size: 22px; color: #3fb950; border: 1px solid #3fb950;">
#
# **"Gantt Chart sahi bana liya = 90% problem solve!"** 📊
#
# </div>
#
# ---
#
# ### **Key Takeaways:**
#
# ✅ **Priority Convention** - Question mein dekho: Lower=High ya Higher=High?
#
# ✅ **Preemptive:** Higher priority aaye → Current ko **turant hatao!**
#
# ✅ **Non-Preemptive:** Higher priority aaye → **Queue mein rakho**, current complete hone do!
#
# ✅ **Tie-Break:** Same priority → **FCFS** (jo pehle aaya wo pehle)
#
# ✅ **Preemptive WT Formula:** `(Last CPU mila) - (Pehle execute kiya) - (Arrival)`
#
# ✅ **Non-Preemptive:** `TAT = CT - AT` and `WT = TAT - BT`
#
# ---
#
# ### **GATE Strategy:** 🎯
#
# | Step | Action |
# |------|--------|
# | 1 | Priority convention check karo |
# | 2 | Preemptive ya Non-Preemptive check karo |
# | 3 | **Gantt Chart CAREFULLY banao** |
# | 4 | Sahi formula use karo |
# | 5 | Double-check calculations! |
#
# ---
#
# <p style="text-align: center; color: #8b949e; font-size: 16px;">
# <strong>Practice karo, Gantt Chart master karo, GATE crack karo! 💪</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #8b949e; text-align: center; margin-top: 20px;">
#
# ---
#
# *Made with ❤️ by Bhai - Your Desi GATE Tutor*
#
# *"Priority Scheduling = VIP Treatment for Processes!"* 👑
#
# ---
#
# </div>
