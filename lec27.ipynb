# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎡 **Round Robin Scheduling - Solved Problem**
# ## *Different Arrival Times Wala Advanced Problem!*
#
# <p style="color: #8b949e; font-size: 16px;">Operating Systems | CPU Scheduling | Bhai Style Complete Solution 🔥</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #30363d;">
#
# ## 🎬 **The Hook - Aaj Ka Challenge!**
#
# ---
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture mein hum ek ADVANCED Round Robin problem solve karenge!** 💥
#
# Bhai, pichle lecture mein humne simple case dekha tha jahan **sab processes ek saath aaye the** (arrival time = 0). Easy tha! 😎
#
# Lekin aaj ka problem **thoda spicy hai** 🌶️:
# - Processes **alag alag time pe arrive** ho rahe hain!
# - Ready Queue manage karna padega!
# - Kaun kab aayega, kab preempt hoga - sab track karna padega!
#
# **Real Life Example:** Imagine karo ek **Doctor's Clinic** 🏥
# - Patients alag alag time pe aate hain
# - Doctor har patient ko sirf **2 minute** deta hai (Time Quantum!)
# - 2 minute baad "Next!" bol deta hai
# - Jo patient abhi tak theek nahi hua, wo wapas line mein lag jata hai!
#
# **Yahi scene hai bhai!** Chalein solve karte hain! 🚀
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ⏪ **Flashback Zone - "Yaad Hai Bhai?"**
#
# ---
#
# Yeh problem solve karne se pehle kuch **important concepts** yaad karte hain... Professor ne assume kiya sab yaad hai! 📚
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔄 **Yaad Hai? #1: Round Robin Ka Basic Funda**
#
# ---
#
# **Round Robin = FCFS + Preemption (Time Quantum ke baad)** 🎡
#
# - Har process ko **fixed time (Time Quantum)** milta hai
# - TQ khatam = **Preempt!** Next process ka turn!
# - Preempted process **Queue ke END mein** jaata hai
# - Golgappe wale bhaiya ki tarah - sabko thoda thoda! 🍜
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔄 **Yaad Hai? #2: Ready Queue Ka Scene**
#
# ---
#
# <pre style="background-color: #161b22; padding: 15px; border-radius: 8px; color: #3fb950; white-space: pre; font-family: monospace;">
# TAIL (New entries)              HEAD (CPU ko jaata hai)
#       │                              │
#       v                              v
#     ┌────┬────┬────┬────┐
#     │ P4 │ P3 │ P2 │ P1 │  ───────> CPU
#     └────┴────┴────┴────┘
#       ^                    ^
#       │                    │
#  Preempted process      First to
#  yahan aata hai!        get CPU!
# </pre>
#
# **Important Rule:** Jab process preempt ho:
# 1. Pehle naye arrive hue processes queue mein aayenge
# 2. **Phir** preempted process TAIL pe jayega!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🔄 **Yaad Hai? #3: Do Cases in Round Robin**
#
# ---
#
# | Case | Situation | Kya Hoga |
# |------|-----------|----------|
# | **Case 1** | Burst Time < TQ | Process **voluntarily** exit karega (Kaam khatam!) |
# | **Case 2** | Burst Time > TQ | Process **preempted** hoga, queue ke end mein jayega |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🔄 **Yaad Hai? #4: Formulas**
#
# ---
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 16px; color: #f0883e;">
#
# **Turnaround Time (TAT) = Completion Time - Arrival Time**
#
# **Waiting Time (WT) = TAT - Burst Time**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ✅ **Basics Clear! Ab Problem Solve Karte Hain!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📝 **Problem Statement**
#
# ---
#
# Consider the set of 5 processes with arrival time and burst time given below. Using **Round Robin Scheduling** with **Time Quantum = 2 units**, calculate:
#
# 1. Average Waiting Time
# 2. Average Turnaround Time
#
# | Process | Arrival Time | Burst Time |
# |---------|-------------|------------|
# | P1 | 0 | 5 |
# | P2 | 1 | 3 |
# | P3 | 2 | 1 |
# | P4 | 3 | 2 |
# | P5 | 4 | 3 |
#
# **Time Quantum (TQ) = 2 units**
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### ⚠️ **Yeh Problem Kyun Tricky Hai?**
#
# ---
#
# **Dekho bhai, yahan DIFFERENT arrival times hain!** 😰
#
# - P1 time 0 pe aata hai
# - P2 time 1 pe aata hai
# - P3 time 2 pe aata hai... aur aise hi!
#
# **Toh hume har time unit pe track karna padega:**
# - Kaun execute ho raha hai?
# - Kaun naya aaya?
# - Ready Queue mein kaun kaun hai?
# - Kab alarm bajega (TQ complete)?
#
# **Chalein step by step solve karte hain!** 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# # 🧠 **Step 1: Gantt Chart Banao (Most Important!)**
#
# ---
#
# **Bhai, Gantt Chart sahi bana liya = 80% problem solve!** 📊
#
# Hum ek **imaginary clock** use karenge aur har time unit pe dekhenge kya ho raha hai! ⏰
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### **⏰ Time = 0**
#
# ---
#
# **Kya hua:**
# - **P1 arrives!** (Arrival time = 0)
# - Sirf P1 hai, toh P1 ko CPU do! ✅
#
# **Ready Queue:** `[ P1 ]` → P1 CPU pe chala gaya → `[ Empty ]`
#
# **Gantt Chart:** `| P1 |`
#
# **P1 remaining burst:** 5 units
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **⏰ Time = 1**
#
# ---
#
# **Kya hua:**
# - P1 still executing (TQ = 2 abhi complete nahi hua)
# - **P2 arrives!** (Arrival time = 1)
# - P2 ko ready queue mein daalo
#
# **Ready Queue:** `[ P2 ]`
#
# **P1 executing:** 1 unit done, 4 remaining
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### **⏰ Time = 2** 🔔 **ALARM BAJAO!**
#
# ---
#
# **Kya hua:**
# - **TQ = 2 complete!** P1 ka time khatam! 🔔
# - P1 **PREEMPTED!** (Remaining = 5-2 = 3 units)
# - **P3 arrives!** (Arrival time = 2)
#
# **Queue Update Order (IMPORTANT!):**
# 1. Pehle naya process add karo: P3 queue mein aaya
# 2. Phir preempted process add karo: P1 queue mein gaya
#
# **Ready Queue:** `[ P1, P3, P2 ]` → P2 CPU pe gaya → `[ P1, P3 ]`
#
# **Gantt Chart:** `| P1(0-2) | P2 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### **⏰ Time = 3**
#
# ---
#
# **Kya hua:**
# - P2 still executing (TQ abhi complete nahi)
# - **P4 arrives!** (Arrival time = 3)
#
# **Ready Queue:** `[ P4, P1, P3 ]`
#
# **P2 executing:** 1 unit done, 2 remaining
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### **⏰ Time = 4** 🔔 **ALARM BAJAO!**
#
# ---
#
# **Kya hua:**
# - **TQ = 2 complete!** P2 ka time khatam! 🔔
# - P2 **PREEMPTED!** (Remaining = 3-2 = 1 unit)
# - **P5 arrives!** (Arrival time = 4)
#
# **Queue Update:**
# 1. P5 queue mein add
# 2. P2 (preempted) queue ke end mein
#
# **Ready Queue:** `[ P2, P5, P4, P1, P3 ]` → P3 CPU pe gaya → `[ P2, P5, P4, P1 ]`
#
# **Gantt Chart:** `| P1(0-2) | P2(2-4) | P3 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **⏰ Time = 5** ✅ **P3 COMPLETE!**
#
# ---
#
# **Kya hua:**
# - P3 ka burst time = 1 (TQ = 2 se kam hai!)
# - P3 **voluntarily releases CPU** (Kaam khatam!) 🎉
# - **No alarm!** (Burst < TQ)
#
# **Ready Queue:** `[ P2, P5, P4, P1 ]` → P1 CPU pe gaya → `[ P2, P5, P4 ]`
#
# **Gantt Chart:** `| P1(0-2) | P2(2-4) | P3(4-5) | P1 |`
#
# **P1 remaining:** 3 units
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### **⏰ Time = 6**
#
# ---
#
# **Kya hua:**
# - P1 executing (1 unit done is round mein)
# - No new arrivals (sab aa chuke hain!)
#
# **Ready Queue:** `[ P2, P5, P4 ]`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### **⏰ Time = 7** 🔔 **ALARM BAJAO!**
#
# ---
#
# **Kya hua:**
# - **TQ = 2 complete!** (P1 executed from 5 to 7)
# - P1 **PREEMPTED!** (Remaining = 3-2 = 1 unit)
#
# **Ready Queue:** `[ P1, P2, P5, P4 ]` → P4 CPU pe gaya → `[ P1, P2, P5 ]`
#
# **Gantt Chart:** `| P1(0-2) | P2(2-4) | P3(4-5) | P1(5-7) | P4 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **⏰ Time = 9** 🔔 ✅ **P4 COMPLETE!**
#
# ---
#
# **Kya hua:**
# - P4 ka burst time = 2 = TQ
# - P4 **COMPLETES exactly at TQ!** 🎉
# - Alarm bhi bajta hai, P4 khatam bhi ho gaya!
#
# **Ready Queue:** `[ P1, P2, P5 ]` → P5 CPU pe gaya → `[ P1, P2 ]`
#
# **Gantt Chart:** `| P1(0-2) | P2(2-4) | P3(4-5) | P1(5-7) | P4(7-9) | P5 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f85149;">
#
# ### **⏰ Time = 11** 🔔 **ALARM BAJAO!**
#
# ---
#
# **Kya hua:**
# - **TQ = 2 complete!** (P5 executed from 9 to 11)
# - P5 **PREEMPTED!** (Remaining = 3-2 = 1 unit)
#
# **Ready Queue:** `[ P5, P1, P2 ]` → P2 CPU pe gaya → `[ P5, P1 ]`
#
# **Gantt Chart:** `| P1 | P2 | P3 | P1 | P4 | P5(9-11) | P2 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **⏰ Time = 12** ✅ **P2 COMPLETE!**
#
# ---
#
# **Kya hua:**
# - P2 ka remaining = 1 unit (TQ = 2 se kam!)
# - P2 **COMPLETES!** 🎉
#
# **Ready Queue:** `[ P5, P1 ]` → P1 CPU pe gaya → `[ P5 ]`
#
# **Gantt Chart:** `| ... | P5(9-11) | P2(11-12) | P1 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### **⏰ Time = 13** ✅ **P1 COMPLETE!**
#
# ---
#
# **Kya hua:**
# - P1 ka remaining = 1 unit
# - P1 **COMPLETES!** 🎉
#
# **Ready Queue:** `[ P5 ]` → P5 CPU pe gaya → `[ Empty ]`
#
# **Gantt Chart:** `| ... | P2(11-12) | P1(12-13) | P5 |`
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **⏰ Time = 14** ✅ **P5 COMPLETE! SAB KHATAM!**
#
# ---
#
# **Kya hua:**
# - P5 ka remaining = 1 unit
# - P5 **COMPLETES!** 🎉
# - **Ready Queue EMPTY!** All processes done! ✅
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #a371f7;">
#
# ## 📊 **Final Gantt Chart:**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌──────┬──────┬──────┬──────┬──────┬──────┬──────┬──────┬──────┐
# │  P1  │  P2  │  P3  │  P1  │  P4  │  P5  │  P2  │  P1  │  P5  │
# │ (2)  │ (2)  │ (1)  │ (2)  │ (2)  │ (2)  │ (1)  │ (1)  │ (1)  │
# └──────┴──────┴──────┴──────┴──────┴──────┴──────┴──────┴──────┘
# 0      2      4      5      7      9      11     12     13     14
# </pre>
#
# **Notice karo:**
# - P1 **3 baar** aaya! (0-2, 5-7, 12-13)
# - P2 **2 baar** aaya! (2-4, 11-12)
# - P5 **2 baar** aaya! (9-11, 13-14)
# - P3, P4 sirf **1 baar** aaye (burst time <= TQ tha!)
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# # 🧮 **Step 2: TAT & WT Calculate Karo!**
#
# ---
#
# ### **Formulas:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 18px; color: #3fb950;">
#
# **TAT = Completion Time - Arrival Time**
#
# **WT = TAT - Burst Time**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### **Step 2a: Completion Time Nikalo (Gantt Chart se!)**
#
# ---
#
# Har process ka **last occurrence** dekho Gantt Chart mein:
#
# | Process | Last Occurrence | Completion Time |
# |---------|----------------|----------------|
# | P1 | 12-13 | **13** |
# | P2 | 11-12 | **12** |
# | P3 | 4-5 | **5** |
# | P4 | 7-9 | **9** |
# | P5 | 13-14 | **14** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### **Step 2b: Turnaround Time Calculate Karo!**
#
# ---
#
# **TAT = Completion Time - Arrival Time**
#
# | Process | CT | AT | TAT = CT - AT |
# |---------|----|----|---------------|
# | P1 | 13 | 0 | 13 - 0 = **13** |
# | P2 | 12 | 1 | 12 - 1 = **11** |
# | P3 | 5 | 2 | 5 - 2 = **3** |
# | P4 | 9 | 3 | 9 - 3 = **6** |
# | P5 | 14 | 4 | 14 - 4 = **10** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### **Step 2c: Waiting Time Calculate Karo!**
#
# ---
#
# **WT = TAT - Burst Time**
#
# | Process | TAT | BT | WT = TAT - BT |
# |---------|-----|----|---------------|
# | P1 | 13 | 5 | 13 - 5 = **8** |
# | P2 | 11 | 3 | 11 - 3 = **8** |
# | P3 | 3 | 1 | 3 - 1 = **2** |
# | P4 | 6 | 2 | 6 - 2 = **4** |
# | P5 | 10 | 3 | 10 - 3 = **7** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📊 **Step 3: Final Calculation Table**
#
# ---
#
# | Process | AT | BT | CT | TAT | WT |
# |---------|----|----|----|----|----|
# | P1 | 0 | 5 | 13 | 13 | 8 |
# | P2 | 1 | 3 | 12 | 11 | 8 |
# | P3 | 2 | 1 | 5 | 3 | 2 |
# | P4 | 3 | 2 | 9 | 6 | 4 |
# | P5 | 4 | 3 | 14 | 10 | 7 |
# | **Total** | | | | **43** | **29** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ## 🎯 **Final Answers!**
#
# ---
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 22px; color: #3fb950;">
#
# **Average Turnaround Time = (13+11+3+6+10)/5 = 43/5 = 8.6 units**
#
# </div>
#
# <br>
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 22px; color: #58a6ff;">
#
# **Average Waiting Time = (8+8+2+4+7)/5 = 29/5 = 5.8 units**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #f85149;">
#
# ## ⚠️ **Common Mistakes - Dhyan Rakhna Bhai!**
#
# ---
#
# ### **❌ Mistake 1: Queue Order Galat Karna**
#
# Jab preemption ho:
# 1. **PEHLE** naye arrive hue processes add karo
# 2. **PHIR** preempted process add karo
#
# ---
#
# ### **❌ Mistake 2: Arrival Time Check Bhoolna**
#
# Har time unit pe check karo: **Koi naya process aaya kya?**
#
# ---
#
# ### **❌ Mistake 3: Remaining Burst Time Track Nahi Karna**
#
# Har preemption ke baad note karo: **Kitna kaam baaki hai?**
#
# ---
#
# ### **❌ Mistake 4: Voluntary Release vs Preemption Confuse Karna**
#
# - **Burst < TQ:** Process khud chhod deta hai (No alarm!)
# - **Burst >= TQ:** Alarm bajta hai, preemption hoti hai
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ## 📋 **Quick Checklist for Round Robin Problems:**
#
# ---
#
# <pre style="background-color: #0d1117; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────────────────────────────────────────────────────────────────────────┐
# |                  ROUND ROBIN SOLVING CHECKLIST                          |
# ├─────────────────────────────────────────────────────────────────────────┤
# |                                                                         |
# |  [ ] Time Quantum note kar liya?                                        |
# |                                                                         |
# |  [ ] Arrival times different hain? (Zyada careful rehna!)               |
# |                                                                         |
# |  [ ] Har time unit pe check kiya:                                       |
# |      - Koi naya process aaya?                                           |
# |      - TQ complete hua? (Alarm!)                                        |
# |      - Process khud khatam ho gaya? (Burst < TQ)                        |
# |                                                                         |
# |  [ ] Ready Queue order sahi hai?                                        |
# |      (New arrivals BEFORE preempted process)                            |
# |                                                                         |
# |  [ ] Remaining burst time track kiya?                                   |
# |                                                                         |
# |  [ ] Gantt Chart complete hai?                                          |
# |                                                                         |
# |  [ ] CT from Gantt Chart (last occurrence)                              |
# |                                                                         |
# |  [ ] TAT = CT - AT                                                      |
# |                                                                         |
# |  [ ] WT = TAT - BT                                                      |
# |                                                                         |
# └─────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎬 **Wrap-Up - Moral of the Story!**
#
# ---
#
# ### **One-Line Summary:**
#
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; font-size: 22px; color: #3fb950; border: 1px solid #3fb950;">
#
# **"Different arrival times = Har time unit pe carefully track karo kaun aaya, kaun gaya!"** ⏰
#
# </div>
#
# ---
#
# ### **Key Takeaways:**
#
# ✅ **Gantt Chart is KING** - Isko sahi banao, baaki sab easy!
#
# ✅ **Clock method use karo** - Har time unit pe check karo events
#
# ✅ **Queue order matters** - New arrivals BEFORE preempted process!
#
# ✅ **Remaining burst track karo** - Kitna kaam baaki hai?
#
# ✅ **Alarm concept** - TQ complete = Preemption time!
#
# ✅ **Voluntary release** - Burst < TQ = No alarm, khud chhod deta hai
#
# ---
#
# ### **Problem Solving Steps:**
#
# ```
# 1. Data note karo (AT, BT, TQ)
# 2. Clock method se Gantt Chart banao
# 3. CT nikalo (Gantt Chart se last occurrence)
# 4. TAT = CT - AT
# 5. WT = TAT - BT
# 6. Averages calculate karo!
# ```
#
# ---
#
# <p style="text-align: center; color: #8b949e; font-size: 16px;">
# <strong>Practice karo, timing dekho, Round Robin master ban jao! 💪</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #8b949e; text-align: center; margin-top: 20px;">
#
# ---
#
# *Made with ❤️ by Bhai - Your Desi OS Tutor*
#
# *"Doctor's clinic jaisa - Sabko baari baari, fair treatment!"* 🏥
#
# ---
#
# </div>
