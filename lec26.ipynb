# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎡 **Round Robin Scheduling Algorithm**
# ## *Sabko Baari Baari Mauka - Fair Play Scheduling!*
#
# <p style="color: #8b949e; font-size: 16px;">Operating Systems - CPU Scheduling Series | Time-Sharing Ka Raja! 👑</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #30363d;">
#
# ## 🎬 **The Hook - Kahani Shuru!**
#
# ---
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture mein hum fodne wale hai Round Robin Scheduling!** 💥
#
# Bhai, kabhi **Golgappe wale bhaiya** ke paas gaye ho? 🍜
#
# Imagine karo:
# - 5 log line mein khade hain
# - Bhaiya kya karta hai? **Ek ek golgappa sabko deta hai turn by turn!**
# - Pehle wale ko 1, doosre ko 1, teesre ko 1...
# - Phir wapas pehle wale pe aata hai!
#
# **Kya bhaiya pehle wale ko 10 golgappe deke baaki ko bhookha rakhta hai?** ❌ NAHI!
#
# **Yahi hai Round Robin ka funda bhai!** Sabko **equal time** milta hai, phir next ka turn! Fair game! 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ⏪ **Flashback Zone - "Yaad Hai Bhai?"**
#
# ---
#
# Ruko bhai! Round Robin samajhne se pehle kuch **basics clear** karna zaroori hai... Professor ne assume kar liya ki sab yaad hai! 📚
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### 🔄 **Yaad Hai? #1: FCFS Kya Tha?**
#
# ---
#
# **FCFS = First Come First Serve**
#
# Jo pehle aaya, uska poora kaam pehle! Bank ki line jaisa! 🏦
#
# **Problem:** Agar pehle wale ka kaam 2 ghante ka hai, baaki sab wait karte reh jayenge! 😫
#
# **Round Robin = FCFS + Preemption** (Improved version!)
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ### 🔄 **Yaad Hai? #2: Preemption Kya Hoti Hai?**
#
# ---
#
# **Preemption = Beech mein CPU cheenna!** 🔄
#
# Process execute ho rahi hai, aur OS bole: *"Time up bhai! Ab doosre ka turn!"*
#
# CPU forcefully le liya jata hai aur next process ko de diya jata hai!
#
# **Round Robin mein GUARANTEED preemption hoti hai** - Time quantum khatam = Preempt! ⏰
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### 🔄 **Yaad Hai? #3: Context Switch Kya Hai?**
#
# ---
#
# Jab ek process se doosri process pe switch karte hain:
#
# 1. **Current process ka state save karo** (Kahan tak kaam hua, kya variables hain, etc.)
# 2. **Next process ka state load karo**
# 3. **Next process ko CPU do!**
#
# **Ye sab time leta hai!** Isliye zyada context switches = Overhead = Bad! ⚠️
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ### 🔄 **Yaad Hai? #4: Circular Queue / FIFO Queue?**
#
# ---
#
# **FIFO Queue:** First In First Out - Jo pehle aaya, wo pehle bahar!
#
# <pre style="background-color: #161b22; padding: 15px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace;">
# HEAD                              TAIL
#   │                                 │
#   v                                 v
# ┌────┬────┬────┬────┬────┐
# │ P1 │ P2 │ P3 │ P4 │ P5 │  <-- New process yahan add hota hai
# └────┴────┴────┴────┴────┘
#   ^
#   │
# CPU isko pick karta hai
# </pre>
#
# **Circular Queue:** End pe jaake wapas start pe aa jao! 🔄
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; color: #c9d1d9; margin: 20px 0; border-radius: 0 10px 10px 0;">
#
# ## ✅ **Basics Clear! Ab Asli Masala!**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# # 🎯 **Round Robin Scheduling - The Main Concept**
#
# ---
#
# ### **Definition (Seedha Point!):**
#
# > **Har process ko ek FIXED TIME (Time Quantum) ke liye CPU milta hai. Time khatam = Next process ka turn! Queue mein wapas line mein lag jao!**
#
# ---
#
# ### **🎡 Real Life Analogy - Merry-Go-Round!**
#
# Bachpan ka jhula yaad hai? Merry-go-round? 🎠
#
# - Har bachche ko **fixed time** ke liye ride milti hai
# - Time khatam = Utro bhai, next bachche ka turn!
# - Agar aur ride chahiye = Line mein wapas lag jao!
# - **Fair hai!** Koi permanently occupy nahi kar sakta!
#
# **CPU bhi aisa hi kaam karta hai Round Robin mein!** 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# ## ⏱️ **Time Quantum - The Heart of Round Robin!**
#
# ---
#
# ### **Kya Hai Time Quantum?**
#
# <div style="background-color: #161b22; padding: 20px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950; border: 1px solid #3fb950;">
#
# **Time Quantum (TQ) = Fixed time slot jo har process ko milta hai!**
#
# *Also called: Time Slice*
#
# </div>
#
# ---
#
# **Typical Value:** 10 to 100 milliseconds
#
# **Example:** Agar TQ = 4ms, toh har process ko sirf 4ms ke liye CPU milega, chahe uska burst time 100ms ho ya 2ms!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ## 🔄 **How Round Robin Works - Step by Step!**
#
# ---
#
# <pre style="background-color: #0d1117; padding: 20px; border-radius: 8px; color: #a371f7; white-space: pre; font-family: monospace; overflow-x: auto;">
#                       ┌─────────────────────────────────────┐
#                       │         READY QUEUE (FIFO)          │
#                       │                                     │
#                       │   HEAD                     TAIL     │
#                       │    │                        │       │
#                       │    v                        v       │
#                       │  ┌────┬────┬────┬────┬────┐         │
#                       │  │ P1 │ P2 │ P3 │ P4 │ P5 │         │
#                       │  └────┴────┴────┴────┴────┘         │
#                       └─────────────────────────────────────┘
#                                      │
#                     ┌────────────────┴────────────────┐
#                     │                                 │
#                     v                                 v
#          ┌─────────────────────┐           ┌─────────────────────┐
#          │   CPU SCHEDULER     │           │       TIMER         │
#          │                     │           │                     │
#          │ Pick HEAD process   │           │  Count Time Quantum │
#          │ Dispatch to CPU     │           │  Interrupt when TQ  │
#          │                     │           │  expires!           │
#          └─────────────────────┘           └─────────────────────┘
#                     │                                 │
#                     └────────────────┬────────────────┘
#                                      │
#                                      v
#                            ┌─────────────────┐
#                            │      CPU        │
#                            │                 │
#                            │   Execute P1    │
#                            │   for 1 TQ      │
#                            └─────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ## 📋 **Algorithm Steps:**
#
# ---
#
# **Step 1:** Ready Queue as **FIFO Queue** maintain karo
#
# **Step 2:** CPU Scheduler **HEAD** se process pick karta hai
#
# **Step 3:** **Timer start** karo = 1 Time Quantum
#
# **Step 4:** Process execute hoti hai...
#
# **Step 5:** Ab **DO cases** ho sakte hain! 👇
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #f0883e;">
#
# ## 🔀 **Two Cases in Round Robin:**
#
# ---
#
# ### **Case 1: Burst Time < Time Quantum** ✅
#
# **Situation:** Process ka kaam Time Quantum se PEHLE khatam ho gaya!
#
# **Example:** TQ = 4ms, Burst Time = 2ms
#
# **Kya hoga:**
# - Process **voluntarily** CPU release kar dega (khud chhod dega)
# - Poora TQ use nahi hoga
# - CPU turant next process ko mil jayega
# - **Process COMPLETE!** Queue se bahar! 🎉
#
# ---
#
# ### **Case 2: Burst Time > Time Quantum** ⚠️
#
# **Situation:** Process ka kaam abhi BAAKI hai, but TQ khatam!
#
# **Example:** TQ = 4ms, Burst Time = 10ms
#
# **Kya hoga:**
# - Timer goes off! **INTERRUPT!** ⏰
# - Process **PREEMPTED** (forcefully hataya gaya)
# - **Context Switch** - State save karo!
# - Process ko **TAIL of Queue** mein daal do
# - Next process ko CPU do!
# - Baad mein wapas turn aayega! 🔄
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ## 🎬 **Visual Example - Queue Movement:**
#
# ---
#
# **TQ = 4ms, P1 burst = 10ms (Case 2 situation)**
#
# <pre style="background-color: #0d1117; padding: 15px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# INITIAL:
# ┌────┬────┬────┐
# │ P1 │ P2 │ P3 │
# └────┴────┴────┘
#   ^
#   │
# P1 gets CPU (4ms ke liye)
#
# AFTER 4ms (P1 preempted, remaining = 6ms):
# ┌────┬────┬────┐
# │ P2 │ P3 │ P1 │  <-- P1 ab TAIL pe hai!
# └────┴────┴────┘
#   ^
#   │
# Ab P2 ka turn!
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #f85149;">
#
# ## ⚠️ **Time Quantum Selection - Bahut Important!**
#
# ---
#
# ### **🔴 TQ bahut BADA ho toh?**
#
# **Problem:** Round Robin = FCFS ban jayega! 😫
#
# **Example:** TQ = 50ms, Process burst = 40ms
#
# Process poora execute ho jayega bina preemption ke... baaki sab wait karenge!
#
# **Result:** Long waiting time for small processes!
#
# ---
#
# ### **🔴 TQ bahut CHHOTA ho toh?**
#
# **Problem:** Too many context switches! 😰
#
# **Example:** TQ = 1ms, Process burst = 10ms
#
# Process ko **10 baar** switch karna padega! Har switch mein time waste!
#
# **Result:** Overhead badh jayega, actual kaam kam hoga!
#
# ---
#
# ### **✅ Ideal TQ:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 18px; color: #3fb950;">
#
# **Balance chahiye! Typically: 10ms to 100ms**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# # 📝 **Solved Example - Step by Step!**
#
# ---
#
# ### **Problem Statement:**
#
# 3 processes hain, sab **time 0 pe arrive** hue:
#
# | Process | Burst Time (ms) |
# |---------|----------------|
# | P1 | 24 |
# | P2 | 3 |
# | P3 | 3 |
#
# **Time Quantum = 4 ms**
#
# **Task:** Gantt Chart banao, Average TAT aur Average WT nikalo!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #3fb950;">
#
# ## 🧠 **Step 1: Gantt Chart Banao!**
#
# ---
#
# **Initial Queue:** P1 → P2 → P3 (All at time 0)
#
# ---
#
# **🕐 Time 0-4:** P1 gets CPU (TQ = 4ms)
# - P1 burst = 24ms, executes 4ms, **remaining = 20ms**
# - P1 **PREEMPTED!** Goes to TAIL
# - Queue: P2 → P3 → P1
#
# ---
#
# **🕐 Time 4-7:** P2 gets CPU
# - P2 burst = 3ms < TQ(4ms)
# - P2 **COMPLETES** in just 3ms! 🎉
# - **Voluntarily releases CPU**
# - Queue: P3 → P1
#
# ---
#
# **🕐 Time 7-10:** P3 gets CPU
# - P3 burst = 3ms < TQ(4ms)
# - P3 **COMPLETES** in 3ms! 🎉
# - Queue: P1 (only remaining)
#
# ---
#
# **🕐 Time 10-14:** P1 gets CPU
# - P1 remaining = 20ms, executes 4ms, **remaining = 16ms**
# - P1 **PREEMPTED!** (But it's the only one, so it gets CPU again)
#
# ---
#
# **🕐 Time 14-18:** P1 again
# - Remaining = 16ms → 12ms
#
# **🕐 Time 18-22:** P1 again
# - Remaining = 12ms → 8ms
#
# **🕐 Time 22-26:** P1 again
# - Remaining = 8ms → 4ms
#
# **🕐 Time 26-30:** P1 again
# - Remaining = 4ms → 0ms
# - P1 **COMPLETES!** 🎉
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9; border: 1px solid #58a6ff;">
#
# ### **📊 Final Gantt Chart:**
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌──────┬─────┬─────┬──────┬──────┬──────┬──────┬──────┐
# │  P1  │ P2  │ P3  │  P1  │  P1  │  P1  │  P1  │  P1  │
# │(4ms) │(3ms)│(3ms)│(4ms) │(4ms) │(4ms) │(4ms) │(4ms) │
# └──────┴─────┴─────┴──────┴──────┴──────┴──────┴──────┘
# 0      4     7     10     14     18     22     26     30
#        ^     ^      ^      ^      ^      ^      ^      ^
#        |     |      |      |      |      |      |      |
#       P1    P2     P3    All are P1 (only process left)
#    preempt done!  done!
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ## 🧮 **Step 2: Turnaround Time & Waiting Time**
#
# ---
#
# ### **Method 1: Standard Formula**
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; text-align: center; font-size: 18px; color: #f0883e;">
#
# **TAT = Completion Time - Arrival Time**
#
# **WT = TAT - Burst Time**
#
# </div>
#
# ---
#
# | Process | Completion | Arrival | TAT | Burst | WT |
# |---------|-----------|---------|-----|-------|----|
# | P1 | 30 | 0 | 30-0 = **30** | 24 | 30-24 = **6** |
# | P2 | 7 | 0 | 7-0 = **7** | 3 | 7-3 = **4** |
# | P3 | 10 | 0 | 10-0 = **10** | 3 | 10-3 = **7** |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ### **Method 2: Direct Waiting Time Formula (Round Robin Special!)**
#
# ---
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 16px; color: #a371f7;">
#
# **WT = (Last Start Time) - (Arrival Time) - (Preemptions × Time Quantum)**
#
# </div>
#
# ---
#
# **For P1:**
# - Last Start Time = 26 (dekho Gantt chart mein last P1 kab start hua)
# - Arrival = 0
# - Preemptions = 5 (kitni baar preempt hua: at 4, 14, 18, 22, 26)
# - **WT = 26 - 0 - (5 × 4) = 26 - 20 = 6 ms** ✅
#
# ---
#
# **For P2:**
# - Last Start Time = 4
# - Arrival = 0
# - Preemptions = 0 (never preempted, completed in first go!)
# - **WT = 4 - 0 - (0 × 4) = 4 ms** ✅
#
# ---
#
# **For P3:**
# - Last Start Time = 7
# - Arrival = 0
# - Preemptions = 0 (completed in first go!)
# - **WT = 7 - 0 - (0 × 4) = 7 ms** ✅
#
# **Same answers dono methods se!** 🎉
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #3fb950;">
#
# ## 📊 **Step 3: Calculate Averages!**
#
# ---
#
# ### **Average Turnaround Time:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950;">
#
# **Avg TAT = (30 + 7 + 10) / 3 = 47/3 = 15.67 ms**
#
# </div>
#
# ---
#
# ### **Average Waiting Time:**
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 8px; text-align: center; font-size: 20px; color: #3fb950;">
#
# **Avg WT = (6 + 4 + 7) / 3 = 17/3 = 5.67 ms**
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 2px solid #58a6ff;">
#
# ## 📋 **Formula Cheat Sheet - Round Robin**
#
# ---
#
# <pre style="background-color: #161b22; padding: 20px; border-radius: 8px; color: #58a6ff; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    ROUND ROBIN FORMULAS                                 │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  METHOD 1 (General - Works for all algorithms):                         │
# │  ─────────────────────────────────────────────                          │
# │  TAT = Completion Time - Arrival Time                                   │
# │  WT  = TAT - Burst Time                                                 │
# │                                                                         │
# │  METHOD 2 (Round Robin Special - Only WT):                              │
# │  ─────────────────────────────────────────                              │
# │  WT = Last Start Time - Arrival Time - (Preemptions x TQ)               │
# │                                                                         │
# │  WHERE:                                                                 │
# │  - Last Start Time = Last time process got CPU                          │
# │  - Preemptions = Number of times process was preempted                  │
# │  - TQ = Time Quantum                                                    │
# │                                                                         │
# │  AVERAGE:                                                               │
# │  ────────                                                               │
# │  Avg = Sum of all values / Number of processes                          │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #a371f7;">
#
# ## 🎯 **Key Characteristics of Round Robin:**
#
# ---
#
# | Property | Value |
# |----------|-------|
# | **Preemptive?** | ✅ YES (Always!) |
# | **Fair?** | ✅ YES (Sabko equal time) |
# | **Starvation?** | ❌ NO (Har process ko turn milega) |
# | **Best For?** | Time-Sharing Systems! |
# | **Context Switches?** | More than FCFS/SJF |
# | **Depends On?** | Time Quantum selection |
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 25px; border-radius: 10px; color: #c9d1d9; border: 1px solid #f0883e;">
#
# ## 🆚 **Round Robin vs Other Algorithms:**
#
# ---
#
# <pre style="background-color: #0d1117; padding: 20px; border-radius: 8px; color: #f0883e; white-space: pre; font-family: monospace; overflow-x: auto;">
# ┌─────────────────────────────────────────────────────────────┐
# │                    COMPARISON                               │
# ├─────────────────────────────────────────────────────────────┤
# │                                                             │
# │   FCFS:   "Jo pehle aaya wo pura kaam kare"                 │
# │           - Simple, No preemption                           │
# │           - Convoy Effect problem                           │
# │                                                             │
# │   SJF:    "Jiska kaam chhota wo pehle"                      │
# │           - Optimal WT, but starvation possible             │
# │           - Burst time predict karna mushkil                │
# │                                                             │
# │   Priority: "Jiska priority zyada wo pehle"                 │
# │           - Good for important tasks                        │
# │           - Starvation possible (solved by aging)           │
# │                                                             │
# │   Round Robin: "Sabko baari baari thoda thoda"              │
# │           - FAIR! Time-sharing best                         │
# │           - No starvation, but more overhead                │
# │                                                             │
# └─────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950;">
#
# # 🎬 **Wrap-Up - Moral of the Story!**
#
# ---
#
# ### **One-Line Summary:**
#
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; font-size: 22px; color: #3fb950; border: 1px solid #3fb950;">
#
# **"Golgappe wale bhaiya ki tarah - Sabko thoda thoda, phir next ka turn!"** 🎡
#
# </div>
#
# ---
#
# ### **Key Takeaways:**
#
# ✅ **Round Robin = FCFS + Preemption** (Time Quantum ke baad forceful switch)
#
# ✅ **Time Quantum** = Fixed time slice for each process (10-100 ms typically)
#
# ✅ **Burst < TQ:** Process voluntarily exits
#
# ✅ **Burst > TQ:** Process preempted, goes to TAIL of queue
#
# ✅ **FAIR algorithm** - No starvation! Sabko turn milega!
#
# ✅ **Best for Time-Sharing Systems** (Multiple users/processes)
#
# ✅ **TQ bahut bada = FCFS jaisa, TQ bahut chhota = Too many context switches**
#
# ---
#
# ### **Exam Tips:** 📝
#
# | Situation | Action |
# |-----------|--------|
# | Gantt Chart banana hai | TQ ke slots mein divide karo, TAIL pe daalo |
# | Sirf WT chahiye | Method 2 use karo (Last Start - AT - Preemptions×TQ) |
# | TAT + WT dono chahiye | Method 1 use karo (Standard formulas) |
# | Process pehle khatam ho gayi | Voluntarily release, no preemption count |
#
# ---
#
# <p style="text-align: center; color: #8b949e; font-size: 16px;">
# <strong>Ab Round Robin clear hai na? Practice karo aur GATE crack karo! 💪</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; color: #8b949e; text-align: center; margin-top: 20px;">
#
# ---
#
# *Made with ❤️ by Bhai - Your Desi OS Tutor*
#
# *"Fair play scheduling - Jaise golgappe wale bhaiya!"* 🎡
#
# ---
#
# </div>
