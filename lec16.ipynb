# %% [markdown]
# <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border: 2px solid #58a6ff;">
# <h1 style="color: #58a6ff; text-align: center; font-size: 2.5em;">🧵 Threads & Multithreading Models</h1>
# <h3 style="color: #8b949e; text-align: center;">"Ek Haath Se Taali Nahi Bajti - Multiple Haath Chahiye!"</h3>
# <p style="color: #3fb950; text-align: center; font-size: 1.2em;">Single Thread vs Multi Thread + Hyperthreading Ka Poora Scene! 🔥</p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# ## 🎬 The Hook - Kahani Shuru!
#
# **To haan ji kaise hai aap sab? Aaj ke iss lecture me hum fodne wale hai Threads aur Multithreading ka poora masala!**
#
# Bhai, kabhi socha hai... jab tum **Chrome browser** use karte ho:
#
# - Ek tab pe **YouTube video** chal rahi hai 🎥
# - Doosre tab pe **file download** ho rahi hai 📥
# - Teesre tab pe tum **Google search** kar rahe ho 🔍
#
# **Ye sab ek saath kaise ho raha hai?** 🤔
#
# Agar browser ek **akela aadmi** hota (Single Thread), toh:
# - Pehle video dekho... ✅
# - Phir download karo... ✅
# - Phir search karo... ✅
#
# **Ek kaam khatam, tab doosra!** Kitna slow na? 😩
#
# But actual mein browser ke andar **multiple workers** (Threads) hain - ek video handle kar raha, ek download, ek search! **Sab ek saath!** 🚀
#
# **Yahi hai Multithreading ka jadoo bhai!**
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 🔙 Yaad Hai? - Flashback Time!
#
# **Lekin aage badhne se pehle, kuch basic concepts yaad hain na bhai? Agar bhool gaye ho to tension nahi, fatafat revise kar lete hain...**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ### 📌 Flashback #1: Process Kya Hai?
#
# **Process** = Program jo **execute ho raha hai**!
#
# | Term | Meaning | Example |
# |------|---------|----------|
# | **Program** | Code jo disk pe pada hai (passive) | chrome.exe file |
# | **Process** | Program jo run ho raha hai (active) | Chrome browser khula |
#
# **Funda:** Jab tum Chrome icon pe double-click karte ho, program se process banta hai!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ### 📌 Flashback #2: CPU Core Kya Hai?
#
# **CPU Core** = Processor ke andar ka **ek worker unit**!
#
# - **Single Core** = Ek worker - ek kaam at a time
# - **Dual Core** = Do workers - do kaam at a time
# - **Quad Core** = Chaar workers - chaar kaam at a time
#
# **Analogy:**
# - 1 Chef = 1 dish at a time
# - 4 Chefs = 4 dishes at a time! 👨‍🍳👨‍🍳👨‍🍳👨‍🍳
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ### 📌 Flashback #3: Blocking System Call Kya Hai?
#
# **Blocking Call** = Jab process ko **wait karna padta hai** kisi operation ke liye!
#
# **Example:**
# ```
# Process: "Mujhe file chahiye disk se!"
# System: "Ruko, disk slow hai, time lagega..."
# Process: *Blocked* - Kuch aur nahi kar sakta jab tak file nahi milti!
# ```
#
# **Problem:** Agar pura process block ho jaye, sab kuch ruk jaata hai! 😰
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #3fb950; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## ✅ Basics Clear! Ab Asli Masala Shuru!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # 🧵 Part 1: Thread Kya Hai? - The Restaurant Kitchen Analogy!
#
# ## Samjho Restaurant Se!
#
# **Process** = **Ek Restaurant** 🍽️
#
# **Thread** = Restaurant ke andar **Individual Workers**! 👨‍🍳
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #58a6ff; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                    PROCESS vs THREAD - RESTAURANT ANALOGY                   │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   RESTAURANT (Process)                                                      │
# │   ┌─────────────────────────────────────────────────────────────────────┐   │
# │   │                                                                     │   │
# │   │   SHARED RESOURCES (Sabke liye common):                             │   │
# │   │   ┌─────────────┬─────────────┬─────────────┐                       │   │
# │   │   │   Kitchen   │  Utensils   │   Menu      │                       │   │
# │   │   │   (Code)    │  (Data)     │   (Files)   │                       │   │
# │   │   └─────────────┴─────────────┴─────────────┘                       │   │
# │   │                                                                     │   │
# │   │   WORKERS (Threads) - Each has own station:                         │   │
# │   │   ┌───────────────┐ ┌───────────────┐ ┌───────────────┐             │   │
# │   │   │   Chef 1      │ │   Chef 2      │ │   Chef 3      │             │   │
# │   │   │   (Thread 1)  │ │   (Thread 2)  │ │   (Thread 3)  │             │   │
# │   │   │               │ │               │ │               │             │   │
# │   │   │ Own Station   │ │ Own Station   │ │ Own Station   │             │   │
# │   │   │ (Stack)       │ │ (Stack)       │ │ (Stack)       │             │   │
# │   │   │               │ │               │ │               │             │   │
# │   │   │ Own Recipe    │ │ Own Recipe    │ │ Own Recipe    │             │   │
# │   │   │ (Registers)   │ │ (Registers)   │ │ (Registers)   │             │   │
# │   │   │               │ │               │ │               │             │   │
# │   │   │ Task ID       │ │ Task ID       │ │ Task ID       │             │   │
# │   │   │ (Thread ID)   │ │ (Thread ID)   │ │ (Thread ID)   │             │   │
# │   │   └───────────────┘ └───────────────┘ └───────────────┘             │   │
# │   │                                                                     │   │
# │   │   All chefs share kitchen, utensils, menu!                          │   │
# │   │   But each has own workstation!                                     │   │
# │   │                                                                     │   │
# │   └─────────────────────────────────────────────────────────────────────┘   │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #58a6ff; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 📝 Thread - Technical Definition
#
# **Thread** = Basic unit of **CPU utilization** / **Execution**!
#
# ### Ek Thread Mein Kya Hota Hai (Unique to each thread):
#
# | Component | Kya Hai | Analogy |
# |-----------|---------|----------|
# | **Thread ID** | Unique identifier | Chef ka ID Card |
# | **Program Counter** | Next instruction kahan hai | Recipe mein kahan tak aaya |
# | **Register Set** | Current working values | Haath mein kya pakda hai |
# | **Stack** | Local variables, function calls | Apna workstation |
#
# ### Kya Share Hota Hai (Common among threads of same process):
#
# | Component | Analogy |
# |-----------|----------|
# | **Code Section** | Same kitchen layout |
# | **Data Section** | Same ingredients |
# | **Files/Resources** | Same utensils, oven |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # 🆚 Single-Threaded vs Multi-Threaded Process
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #3fb950; background-color: #161b22; padding: 25px; border-radius: 8px;">
# ┌────────────────────────────────────────────────────────────────────────────────────┐
# │               SINGLE-THREADED vs MULTI-THREADED PROCESS                            │
# ├────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                                    │
# │   SINGLE-THREADED                           MULTI-THREADED                         │
# │   (Traditional/Heavyweight)                 (Modern/Efficient)                     │
# │                                                                                    │
# │   ┌─────────────────────┐                   ┌─────────────────────┐                │
# │   │      PROCESS        │                   │      PROCESS        │                │
# │   ├─────────────────────┤                   ├─────────────────────┤                │
# │   │  Code  │  Data      │                   │  Code  │  Data      │  SHARED        │
# │   ├────────┴────────────┤                   ├────────┴────────────┤                │
# │   │       Files         │                   │       Files         │                │
# │   ├─────────────────────┤                   ├─────────────────────┤                │
# │   │                     │                   │                     │                │
# │   │   ┌───────────┐     │                   │ ┌─────┐┌─────┐┌─────┐│               │
# │   │   │  Thread   │     │                   │ │ T1  ││ T2  ││ T3  ││               │
# │   │   │           │     │                   │ ├─────┤├─────┤├─────┤│               │
# │   │   │ Registers │     │                   │ │Regs ││Regs ││Regs ││  SEPARATE     │
# │   │   │   Stack   │     │                   │ │Stack││Stack││Stack││               │
# │   │   └───────────┘     │                   │ └─────┘└─────┘└─────┘│               │
# │   │                     │                   │                     │                │
# │   │   ONE task at a     │                   │   MULTIPLE tasks    │                │
# │   │   time only!        │                   │   simultaneously!   │                │
# │   │                     │                   │                     │                │
# │   └─────────────────────┘                   └─────────────────────┘                │
# │                                                                                    │
# │   Like: 1 Chef kitchen                      Like: 3 Chef kitchen                   │
# │   Slow, sequential                          Fast, parallel                         │
# │                                                                                    │
# └────────────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 🌐 Real Example - Chrome Browser!
#
# **Chrome ek Multi-Threaded Process hai!**
#
# | Thread | Kya Karta Hai |
# |--------|---------------|
# | Thread 1 | Web page display karna |
# | Thread 2 | File download handle karna |
# | Thread 3 | User input (typing, clicking) process karna |
# | Thread 4 | Network requests handle karna |
# | Thread 5 | JavaScript execute karna |
#
# **Result:** Tum video dekh sakte ho WHILE download ho raha hai! 🎉
#
# **Agar Single-Threaded hota:**
# ```
# Download shuru... *freeze*
# Page display... NOPE! Wait for download!
# User click kiya... NOPE! Wait!
# ```
# 😤 Kitna frustrating!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # 🎁 Part 2: Benefits of Multithreading - 4 Superpowers!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #f0883e; background-color: #161b22; padding: 25px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                    4 BENEFITS OF MULTITHREADING                             │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   1. RESPONSIVENESS                                                         │
# │   ─────────────────                                                         │
# │   Program never freezes!                                                    │
# │   One thread blocked? Others still work!                                    │
# │   "Ek chef busy? Doosra serve karega!"                                      │
# │                                                                             │
# │   2. RESOURCE SHARING                                                       │
# │   ────────────────────                                                      │
# │   Threads share code, data, files!                                          │
# │   No duplicate resources needed!                                            │
# │   "Ek kitchen, multiple chefs - utensils share!"                            │
# │                                                                             │
# │   3. ECONOMY                                                                │
# │   ────────                                                                  │
# │   Thread creation is CHEAPER than process creation!                         │
# │   Context switch between threads is FASTER!                                 │
# │   "New chef hire karna cheaper than new restaurant!"                        │
# │                                                                             │
# │   4. MULTIPROCESSOR UTILIZATION                                             │
# │   ─────────────────────────────                                             │
# │   Multiple threads = Multiple CPUs use ho sakte!                            │
# │   TRUE parallelism possible!                                                │
# │   "4 chefs on 4 stoves - 4x faster!"                                        │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 1️⃣ Responsiveness - "Never Freeze!"
#
# **Problem without multithreading:**
# ```
# User: *clicks button*
# App: "Ruko, file download ho raha hai..."
# User: *frustrated* 😤
# ```
#
# **With multithreading:**
# ```
# Thread 1: Downloads file (background mein)
# Thread 2: Handles user clicks (foreground mein)
# User: *happy* 😊
# ```
#
# **Funda:** Ek thread block hua toh baaki kaam karte rehte hain!
#
# ---
#
# ## 2️⃣ Resource Sharing - "Sharing is Caring!"
#
# **Threads automatically share:**
# - Code section (same program logic)
# - Data section (same variables)
# - Open files (same file handles)
#
# **Benefit:** Multiple activities in SAME address space!
#
# ---
#
# ## 3️⃣ Economy - "Budget Friendly!"
#
# | Operation | Process | Thread |
# |-----------|---------|--------|
# | **Creation** | Expensive (new memory, resources) | Cheap (shares parent's resources) |
# | **Context Switch** | Slow (save/restore everything) | Fast (less to save/restore) |
#
# ---
#
# ## 4️⃣ Multiprocessor Utilization - "Use All CPUs!"
#
# **Single-threaded on 4-core CPU:**
# ```
# Core 1: [Working]
# Core 2: [Idle]
# Core 3: [Idle]     75% waste!
# Core 4: [Idle]
# ```
#
# **Multi-threaded on 4-core CPU:**
# ```
# Core 1: [Thread 1]
# Core 2: [Thread 2]
# Core 3: [Thread 3]  100% utilization!
# Core 4: [Thread 4]
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # 👤 Part 3: Types of Threads - User vs Kernel!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #58a6ff; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                    USER THREADS vs KERNEL THREADS                           │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   USER LEVEL                                                                │
# │   ──────────                                                                │
# │   ┌─────────────────────────────────────────────────────────────────────┐   │
# │   │                                                                     │   │
# │   │   ┌──────────┐  ┌──────────┐  ┌──────────┐                          │   │
# │   │   │ User     │  │ User     │  │ User     │   Created by             │   │
# │   │   │ Thread 1 │  │ Thread 2 │  │ Thread 3 │   developers/users       │   │
# │   │   └──────────┘  └──────────┘  └──────────┘                          │   │
# │   │                                                                     │   │
# │   │   Managed by Thread Library (user space)                            │   │
# │   │   Kernel doesn't know about these!                                  │   │
# │   │                                                                     │   │
# │   └─────────────────────────────────────────────────────────────────────┘   │
# │                                                                             │
# │   ═══════════════════════════════════════════════════════════════════════   │
# │                              KERNEL LEVEL                                   │
# │   ═══════════════════════════════════════════════════════════════════════   │
# │                                                                             │
# │   ┌─────────────────────────────────────────────────────────────────────┐   │
# │   │                                                                     │   │
# │   │   ┌──────────┐  ┌──────────┐  ┌──────────┐                          │   │
# │   │   │ Kernel   │  │ Kernel   │  │ Kernel   │   Managed directly       │   │
# │   │   │ Thread 1 │  │ Thread 2 │  │ Thread 3 │   by Operating System    │   │
# │   │   └──────────┘  └──────────┘  └──────────┘                          │   │
# │   │                                                                     │   │
# │   │   OS has full control and visibility                                │   │
# │   │                                                                     │   │
# │   └─────────────────────────────────────────────────────────────────────┘   │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #a371f7; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 📊 User Threads vs Kernel Threads
#
# | Feature | User Threads | Kernel Threads |
# |---------|--------------|----------------|
# | **Managed by** | Thread Library (user space) | Operating System |
# | **Visibility to Kernel** | Invisible | Visible |
# | **Creation** | Fast (no system call) | Slower (needs system call) |
# | **Analogy** | Employees hired by manager | Employees hired by company |
#
# **Key Question:** User threads ko kaam karna hai, but kernel threads CPU pe run karte hain. **Dono mein relationship kaise banega?**
#
# **Yahi sikhate hain Multithreading Models mein!** 🎯
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # 🔗 Part 4: Multithreading Models - 3 Ways to Connect!
#
# User threads ko kernel threads se **kaise map karein**?
#
# **Teen Models hain bhai:**
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 1️⃣ Many-to-One Model
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #f85149; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                         MANY-TO-ONE MODEL                                   │
# │                    "Ek Ticket Counter, Bahut Log!"                          │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   USER THREADS                                                              │
# │                                                                             │
# │       ┌────┐    ┌────┐    ┌────┐    ┌────┐                                  │
# │       │ U1 │    │ U2 │    │ U3 │    │ U4 │                                  │
# │       └──┬─┘    └──┬─┘    └──┬─┘    └──┬─┘                                  │
# │          │         │         │         │                                    │
# │          └─────────┴────┬────┴─────────┘                                    │
# │                         │                                                   │
# │                         ▼                                                   │
# │                     ┌──────┐                                                │
# │                     │  K1  │    KERNEL THREAD (sirf 1!)                     │
# │                     └──────┘                                                │
# │                                                                             │
# │   ADVANTAGES:                                                               │
# │   - Thread management in user space (efficient)                             │
# │                                                                             │
# │   DISADVANTAGES:                                                            │
# │   - One thread blocks = ENTIRE process blocks!                              │
# │   - Cannot use multiple processors!                                         │
# │     (4 CPUs hain but sirf 1 use hoga!)                                      │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# **Analogy:** Railway station pe **1 ticket counter**, 100 log line mein!
# - Counter pe koi atak gaya → **sab wait karenge!** 😤
# - 4 counters khole hain (4 CPUs) but sirf **1 use** ho raha!
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 2️⃣ One-to-One Model
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #3fb950; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                         ONE-TO-ONE MODEL                                    │
# │                   "Har Aadmi Ka Apna Counter!"                              │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   USER THREADS                                                              │
# │                                                                             │
# │       ┌────┐    ┌────┐    ┌────┐    ┌────┐                                  │
# │       │ U1 │    │ U2 │    │ U3 │    │ U4 │                                  │
# │       └──┬─┘    └──┬─┘    └──┬─┘    └──┬─┘                                  │
# │          │         │         │         │                                    │
# │          │         │         │         │    (1:1 mapping)                   │
# │          ▼         ▼         ▼         ▼                                    │
# │       ┌────┐    ┌────┐    ┌────┐    ┌────┐                                  │
# │       │ K1 │    │ K2 │    │ K3 │    │ K4 │   KERNEL THREADS                 │
# │       └────┘    └────┘    └────┘    └────┘                                  │
# │                                                                             │
# │   ADVANTAGES:                                                               │
# │   - More concurrency (one blocks, others run!)                              │
# │   - Can use multiple processors!                                            │
# │                                                                             │
# │   DISADVANTAGES:                                                            │
# │   - Creating user thread = Creating kernel thread (expensive!)              │
# │   - Number of threads RESTRICTED by system                                  │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# **Analogy:** Har customer ka **apna dedicated counter!**
# - Ek atak gaya → **baaki chalu!** ✅
# - But bahut counters banana = **expensive!** 💰
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 3️⃣ Many-to-Many Model (BEST!) ⭐
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #58a6ff; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                        MANY-TO-MANY MODEL                                   │
# │                  "Flexible Counter System!"                                 │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   USER THREADS                                                              │
# │                                                                             │
# │       ┌────┐    ┌────┐    ┌────┐    ┌────┐    ┌────┐                        │
# │       │ U1 │    │ U2 │    │ U3 │    │ U4 │    │ U5 │                        │
# │       └──┬─┘    └──┬─┘    └──┬─┘    └──┬─┘    └──┬─┘                        │
# │          │         │         │         │         │                          │
# │          └────┬────┴────┬────┴────┬────┴────┬────┘                          │
# │               │         │         │         │                               │
# │               ▼         ▼         ▼         ▼                               │
# │            ┌────┐    ┌────┐    ┌────┐    ┌────┐                             │
# │            │ K1 │    │ K2 │    │ K3 │    │ K4 │   KERNEL THREADS            │
# │            └────┘    └────┘    └────┘    └────┘                             │
# │                                                                             │
# │   Many user threads mapped to smaller/equal kernel threads!                 │
# │                                                                             │
# │   ADVANTAGES (Best of Both Worlds!):                                        │
# │   - Create as many user threads as needed!                                  │
# │   - Run in parallel on multiprocessor!                                      │
# │   - One blocks? Kernel schedules another!                                   │
# │   - Flexible mapping!                                                       │
# │                                                                             │
# │   USED IN: Most modern operating systems!                                   │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# **Analogy:** **Smart queue management!** Multiple counters, flexible assignment!
# - Jitne chahiye utne customers handle karo
# - Available counters efficiently use karo!
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 📊 Models Comparison Table
#
# | Feature | Many-to-One | One-to-One | Many-to-Many |
# |---------|-------------|------------|---------------|
# | **Mapping** | N user → 1 kernel | 1 user → 1 kernel | N user → M kernel |
# | **Blocking** | All blocked | Only one blocked | Only one blocked |
# | **Multiprocessor** | Cannot use | Can use | Can use |
# | **Thread creation** | Cheap | Expensive | Flexible |
# | **Best for** | Old systems | Limited threads | Modern systems |
# | **Rating** | ⭐ | ⭐⭐ | ⭐⭐⭐ |
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; color: #c9d1d9;">
#
# # ⚡ Part 5: Hyperthreading - Double the Power!
#
# ## Also called: Simultaneous Multithreading (SMT)
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #a371f7; background-color: #161b22; padding: 25px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                         HYPERTHREADING                                      │
# │               "Ek Physical Core = Do Logical Cores!"                        │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │   WITHOUT HYPERTHREADING:                                                   │
# │   ─────────────────────────                                                 │
# │                                                                             │
# │   Physical Cores: 2                                                         │
# │   Logical Processors: 2                                                     │
# │   Threads at once: 2                                                        │
# │                                                                             │
# │   ┌──────────────┐    ┌──────────────┐                                      │
# │   │   Core 1     │    │   Core 2     │                                      │
# │   │  [Thread 1]  │    │  [Thread 2]  │                                      │
# │   └──────────────┘    └──────────────┘                                      │
# │                                                                             │
# │   ═══════════════════════════════════════════════════════════════════════   │
# │                                                                             │
# │   WITH HYPERTHREADING:                                                      │
# │   ─────────────────────                                                     │
# │                                                                             │
# │   Physical Cores: 2                                                         │
# │   Logical Processors: 4 (2 x 2)                                             │
# │   Threads at once: 4                                                        │
# │                                                                             │
# │   ┌──────────────────────────┐    ┌──────────────────────────┐              │
# │   │        Core 1            │    │        Core 2            │              │
# │   │  ┌──────────┬──────────┐ │    │  ┌──────────┬──────────┐ │              │
# │   │  │ Logical  │ Logical  │ │    │  │ Logical  │ Logical  │ │              │
# │   │  │ Core 1   │ Core 2   │ │    │  │ Core 3   │ Core 4   │ │              │
# │   │  │[Thread1] │[Thread2] │ │    │  │[Thread3] │[Thread4] │ │              │
# │   │  └──────────┴──────────┘ │    │  └──────────┴──────────┘ │              │
# │   └──────────────────────────┘    └──────────────────────────┘              │
# │                                                                             │
# │   Like having 4 processors instead of 2!                                    │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #58a6ff; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 📝 Hyperthreading Explained Simply
#
# **What is it?**
# > Physical cores ko **logically divide** karke **more threads** support karna!
#
# **How it works:**
# - 1 Physical Core → 2 Logical Processors
# - 2 Physical Cores → 4 Logical Processors
# - 4 Physical Cores → 8 Logical Processors
#
# **Analogy:**
# - Physical Core = **Ek desk**
# - Without HT = **1 person per desk**
# - With HT = **2 people share desk** (jab ek break pe, doosra kaam kare!)
#
# **Intel's Marketing Name:** Hyperthreading
# **Technical Name:** Simultaneous Multithreading (SMT)
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# ## 💻 How to Check Hyperthreading on Your PC?
#
# **Windows Command Prompt mein:**
#
# ```cmd
# wmic
# cpu get NumberOfCores, NumberOfLogicalProcessors
# ```
#
# **Result interpretation:**
#
# | Cores | Logical Processors | Hyperthreading? |
# |-------|-------------------|------------------|
# | 2 | 2 | NO ❌ |
# | 2 | 4 | YES ✅ |
# | 4 | 4 | NO ❌ |
# | 4 | 8 | YES ✅ |
#
# **Rule:** If Logical > Physical → Hyperthreading enabled! 🎉
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 30px; border-radius: 15px; border: 2px solid #3fb950; margin-top: 20px;">
#
# # 🎯 Wrap-Up - Moral of the Story!
#
# <div style="color: #c9d1d9; font-size: 1.1em;">
#
# ## Thread:
# > **"Thread = Process ke andar ka worker! Multiple workers = Multiple tasks simultaneously!"** 🧵
#
# ## Multithreading Benefits:
# > **"Responsiveness, Resource Sharing, Economy, Multiprocessor Utilization - RREM yaad rakhna!"** 🎁
#
# ## Models:
# > **"Many-to-One = Slow, One-to-One = Expensive, Many-to-Many = BEST!"** 🏆
#
# ## Hyperthreading:
# > **"1 Core = 2 Logical Processors = Double the power, same hardware!"** ⚡
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 25px; border-radius: 10px; margin-top: 15px; color: #c9d1d9;">
#
# ## 📝 Final Takeaways:
#
# ### Thread Basics:
# 1. **Thread** = Basic unit of CPU utilization
# 2. **Contains:** Thread ID, Program Counter, Registers, Stack
# 3. **Shares:** Code, Data, Files with other threads in same process
#
# ### Benefits (RREM):
# 1. **R**esponsiveness - Never freeze
# 2. **R**esource Sharing - Efficient
# 3. **E**conomy - Cheaper than processes
# 4. **M**ultiprocessor Utilization - Use all CPUs
#
# ### Thread Types:
# 1. **User Threads** - Managed in user space
# 2. **Kernel Threads** - Managed by OS
#
# ### Models:
# 1. **Many-to-One** - N:1 (bad for multiprocessor)
# 2. **One-to-One** - 1:1 (expensive creation)
# 3. **Many-to-Many** - N:M (best, flexible)
#
# ### Hyperthreading:
# - Physical cores → Logical processors
# - Doubles thread capacity without extra hardware
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; border-left: 5px solid #f0883e; padding: 20px; margin: 15px 0; border-radius: 8px; color: #c9d1d9;">
#
# ## 🧠 Quick Memory Tricks!
#
# **Thread Components (TIPS):**
# ```
# T - Thread ID
# I - (Program Counter) Instruction pointer
# P - (Registers) Processing values
# S - Stack
# ```
#
# **Benefits (RREM):**
# ```
# "Responsive Restaurants have
#  Resources shared,
#  Economy maintained, and
#  Multiple chefs working!"
# ```
#
# **Models:**
# ```
# "Many-One = Bottleneck
#  One-One = Expensive
#  Many-Many = Balanced!"
# ```
#
# **Hyperthreading:**
# ```
# "Logical > Physical = HT enabled!"
# ```
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; color: #c9d1d9;">
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #58a6ff; background-color: #161b22; padding: 20px; border-radius: 8px;">
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                        THREADS - COMPLETE PICTURE                           │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                             │
# │                              PROCESS                                        │
# │                                 │                                           │
# │                    ┌────────────┴────────────┐                              │
# │                    │                         │                              │
# │             Single-Threaded            Multi-Threaded                       │
# │             (1 worker)                 (Many workers)                       │
# │                                             │                               │
# │                           ┌─────────────────┼─────────────────┐             │
# │                           │                 │                 │             │
# │                      User Threads     Kernel Threads    Hyperthreading      │
# │                           │                 │                               │
# │                           └────────┬────────┘                               │
# │                                    │                                        │
# │                           MULTITHREADING MODELS                             │
# │                                    │                                        │
# │                    ┌───────────────┼───────────────┐                        │
# │                    │               │               │                        │
# │              Many-to-One      One-to-One     Many-to-Many                   │
# │                (Bad)          (Costly)         (Best)                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# </pre>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; text-align: center; color: #58a6ff; font-size: 1.3em;">
#
# **"Ab Threads aur Multithreading complete clear! 🚀**
#
# **Ek haath se taali nahi bajti - Multiple threads se bajti hai!"** 👏
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; text-align: center; color: #8b949e;">
#
# ---
#
# *Notes by Bhai - Your Desi Tech Tutor* 🎓
#
# *"Complex concepts, Simple explanations - Restaurant se CPU tak!"*
#
# ---
#
# </div>
